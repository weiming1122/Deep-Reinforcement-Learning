# %%
# %%capture
# Clone the repository
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents

# %%
# %%capture
# Go inside the repository and install the package
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %%
# Here, we create training-envs-executables and linux
# !mkdir ./training-envs-executables
# !mkdir ./training-envs-executables/linux

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://drive.usercontent.google.com/download?id=1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL&export=download&authuser=0' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL&export=download&authuser=0" -O ./training-envs-executables/linux/SoccerTwos.zip && rm -rf /tmp/cookies.txt
# Out:
# --2024-01-04 10:34:27--  https://docs.google.com/uc?export=download&confirm=&id=1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL&export=download&authuser=0
# Resolving docs.google.com (docs.google.com)... 142.250.101.102, 142.250.101.100, 142.250.101.101, ...
# Connecting to docs.google.com (docs.google.com)|142.250.101.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-10-28-docs.googleusercontent.com/docs/securesc/gsh555dforjvovgj5j8hk7f4dk8ulc54/an2aj4mr903u5vq6oqqg3dse9ne1bbmv/1704364425000/09764732090272539193/01349009940183986922Z/1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL?e=download&uuid=63512c4b-bf80-4c8a-9a2d-da45fcb3057f [following]
# --2024-01-04 10:34:27--  https://doc-10-28-docs.googleusercontent.com/docs/securesc/gsh555dforjvovgj5j8hk7f4dk8ulc54/an2aj4mr903u5vq6oqqg3dse9ne1bbmv/1704364425000/09764732090272539193/01349009940183986922Z/1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL?e=download&uuid=63512c4b-bf80-4c8a-9a2d-da45fcb3057f
# ...

# %%
# !wget --no-check-certificate 'https://drive.usercontent.google.com/download?id=1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL&export=download&authuser=0' -O ./training-envs-executables/linux/SoccerTwos.zip

# %%
# %%capture
# !unzip -d ./training-envs-executables/linux/SoccerTwos ./training-envs-executables/linux/SoccerTwos.zip

# %%
# !chmod -R 755 ./training-envs-executables/linux/SoccerTwos

# %%
./config/poca/SoccerTwos.yaml

behaviors:
  SoccerTwos:
    trainer_type: poca
    hyperparameters:
      batch_size: 2048
      buffer_size: 20480
      learning_rate: 0.0003
      beta: 0.005
      epsilon: 0.2
      lambd: 0.95
      num_epoch: 3
      learning_rate_schedule: constant
    network_settings:
      normalize: false
      hidden_units: 512
      num_layers: 2
      vis_encode_type: simple
    reward_signals:
      extrinsic:
        gamma: 0.99
        strength: 1.0
    keep_checkpoints: 5
    max_steps: 8000000
    time_horizon: 1000
    summary_freq: 10000
    self_play:
      save_steps: 50000
      team_change: 250000
      swap_steps: 20000
      window: 10
      play_against_latest_model_ratio: 0.5
      initial_elo: 1200.0

# %%
# !mlagents-learn ./config/poca/SoccerTwos.yaml --env=./training-envs-executables/linux/SoccerTwos/SoccerTwos --run-id="SoccerTwos" --no-graphics
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:614: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
# ...

# %%
from huggingface_hub import notebook_login
notebook_login()

# !huggingface-cli login --token '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'

# %%
# !mlagents-push-to-hf --run-id="SoccerTwos" --local-dir="./results/SoccerTwos" --repo-id="Weiming1122/poca-SoccerTwos" --commit-message="First Push"
# Out:
# [INFO] This function will create a model card and upload your SoccerTwos into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo SoccerTwos to the Hugging Face Hub
# SoccerTwos-6499922.onnx:   0% 0.00/1.77M [00:00<?, ?B/s]
# SoccerTwos-6499922.pt:   0% 0.00/28.4M [00:00<?, ?B/s]
#
# SoccerTwos-6999980.onnx:   0% 0.00/1.77M [00:00<?, ?B/s]
#
#
# SoccerTwos-6999980.pt:   0% 0.00/28.4M [00:00<?, ?B/s]
#
#
#
# Upload 13 LFS files:   0% 0/13 [00:00<?, ?it/s]
#
#
#
#
# SoccerTwos-6499922.onnx:   1% 16.4k/1.77M [00:00<01:08, 25.4kB/s]
#
#
# SoccerTwos-6999980.pt:   0% 16.4k/28.4M [00:00<18:42, 25.3kB/s]
# SoccerTwos-6499922.pt:   0% 16.4k/28.4M [00:00<19:20, 24.5kB/s]
#
#
#
#
# SoccerTwos-7499992.onnx:   1% 16.4k/1.77M [00:00<01:10, 24.9kB/s]
#
# SoccerTwos-6999980.onnx:   1% 16.4k/1.77M [00:00<01:11, 24.5kB/s]
# SoccerTwos-6499922.pt:   8% 2.20M/28.4M [00:00<00:06, 3.78MB/s]
# ...
