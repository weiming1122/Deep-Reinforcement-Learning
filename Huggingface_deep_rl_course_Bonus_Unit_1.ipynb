# %%
# %%capture
# Clone the repository (can take 3min)
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents

# %%
# %%capture
# Go inside the repository and install the package (can take 3min)
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %%
# !mkdir ./trained-envs-executables
# !mkdir ./trained-envs-executables/linux

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF" -O ./trained-envs-executables/linux/Huggy.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-12-14 05:33:08--  https://docs.google.com/uc?export=download&confirm=t&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF
# Resolving docs.google.com (docs.google.com)... 142.250.128.138, 142.250.128.100, 142.250.128.113, ...
# Connecting to docs.google.com (docs.google.com)|142.250.128.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5rjkhb59n14iemucbh43gisl63s72n9u/1702531950000/15803371278684422230/*/1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF?e=download&uuid=bc746d14-c0f6-49a4-8dab-d4d2deee57e6 [following]
# Warning: wildcards not supported in HTTP.
# --2023-12-14 05:33:09--  https://doc-0k-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5rjkhb59n14iemucbh43gisl63s72n9u/1702531950000/15803371278684422230/*/1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF?e=download&uuid=bc746d14-c0f6-49a4-8dab-d4d2deee57e6
# Resolving doc-0k-28-docs.googleusercontent.com (doc-0k-28-docs.googleusercontent.com)... 172.217.214.132, 2607:f8b0:4001:c05::84
# Connecting to doc-0k-28-docs.googleusercontent.com (doc-0k-28-docs.googleusercontent.com)|172.217.214.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39214997 (37M) [application/x-zip-compressed]
# Saving to: ‘./trained-envs-executables/linux/Huggy.zip’
#
# ./trained-envs-exec 100%[===================>]  37.40M   115MB/s    in 0.3s
#
# 2023-12-14 05:33:09 (115 MB/s) - ‘./trained-envs-executables/linux/Huggy.zip’ saved [39214997/39214997]

# %%
# %%capture
# !unzip -d ./trained-envs-executables/linux/ ./trained-envs-executables/linux/Huggy.zip

# %%
# !chmod -R 755 ./trained-envs-executables/linux/Huggy

# %%
# !mlagents-learn ./config/ppo/Huggy.yaml --env=./trained-envs-executables/linux/Huggy/Huggy --run-id="Huggy" --no-graphics
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:614: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)
# 2023-12-14 06:21:29.611665: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-14 06:21:29.611728: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-14 06:21:29.611773: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-14 06:21:29.621087: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0.dev0,
#   ml-agents-envs: 1.1.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.1.1+cu121
# [INFO] Connected to Unity environment with package version 2.2.1-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: Huggy?team=0
# [INFO] Hyperparameters for behavior name Huggy:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	2048
# 	  buffer_size:	20480
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	200000
# 	network_settings:
# 	  normalize:	True
# 	  hidden_units:	512
# 	  num_layers:	3
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.995
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	init_path:	None
# 	keep_checkpoints:	15
# 	even_checkpoints:	False
# 	max_steps:	2000000
# 	time_horizon:	1000
# 	summary_freq:	50000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] Huggy. Step: 50000. Time Elapsed: 78.687 s. Mean Reward: 1.702. Std of Reward: 0.846. Training.
# [INFO] Huggy. Step: 100000. Time Elapsed: 142.016 s. Mean Reward: 2.355. Std of Reward: 0.960. Training.
# [INFO] Huggy. Step: 150000. Time Elapsed: 206.893 s. Mean Reward: 2.997. Std of Reward: 1.111. Training.
# [INFO] Huggy. Step: 200000. Time Elapsed: 269.707 s. Mean Reward: 3.213. Std of Reward: 1.315. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-199930.onnx
# [INFO] Huggy. Step: 250000. Time Elapsed: 341.027 s. Mean Reward: 3.498. Std of Reward: 1.463. Training.
# [INFO] Huggy. Step: 300000. Time Elapsed: 408.396 s. Mean Reward: 3.507. Std of Reward: 1.748. Training.
# [INFO] Huggy. Step: 350000. Time Elapsed: 470.376 s. Mean Reward: 3.551. Std of Reward: 1.779. Training.
# [INFO] Huggy. Step: 400000. Time Elapsed: 539.528 s. Mean Reward: 3.741. Std of Reward: 1.868. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-399939.onnx
# [INFO] Huggy. Step: 450000. Time Elapsed: 603.022 s. Mean Reward: 3.433. Std of Reward: 2.136. Training.
# [INFO] Huggy. Step: 500000. Time Elapsed: 671.584 s. Mean Reward: 3.512. Std of Reward: 2.014. Training.
# [INFO] Huggy. Step: 550000. Time Elapsed: 738.849 s. Mean Reward: 3.695. Std of Reward: 2.057. Training.
# [INFO] Huggy. Step: 600000. Time Elapsed: 806.842 s. Mean Reward: 3.563. Std of Reward: 2.037. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-599930.onnx
# [INFO] Huggy. Step: 650000. Time Elapsed: 870.816 s. Mean Reward: 3.571. Std of Reward: 2.031. Training.
# [INFO] Huggy. Step: 700000. Time Elapsed: 938.097 s. Mean Reward: 3.649. Std of Reward: 2.089. Training.
# [INFO] Huggy. Step: 750000. Time Elapsed: 1005.420 s. Mean Reward: 3.564. Std of Reward: 2.164. Training.
# [INFO] Huggy. Step: 800000. Time Elapsed: 1070.487 s. Mean Reward: 3.624. Std of Reward: 2.033. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-799940.onnx
# [INFO] Huggy. Step: 850000. Time Elapsed: 1140.398 s. Mean Reward: 3.576. Std of Reward: 2.001. Training.
# [INFO] Huggy. Step: 900000. Time Elapsed: 1205.709 s. Mean Reward: 3.621. Std of Reward: 2.060. Training.
# [INFO] Huggy. Step: 950000. Time Elapsed: 1278.898 s. Mean Reward: 3.579. Std of Reward: 2.151. Training.
# [INFO] Huggy. Step: 1000000. Time Elapsed: 1346.381 s. Mean Reward: 3.615. Std of Reward: 2.091. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-999975.onnx
# [INFO] Huggy. Step: 1050000. Time Elapsed: 1413.641 s. Mean Reward: 3.638. Std of Reward: 2.030. Training.
# [INFO] Huggy. Step: 1100000. Time Elapsed: 1482.838 s. Mean Reward: 3.698. Std of Reward: 2.032. Training.
# [INFO] Huggy. Step: 1150000. Time Elapsed: 1550.788 s. Mean Reward: 3.824. Std of Reward: 2.084. Training.
# [INFO] Huggy. Step: 1200000. Time Elapsed: 1620.425 s. Mean Reward: 3.691. Std of Reward: 1.902. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1199259.onnx
# [INFO] Huggy. Step: 1250000. Time Elapsed: 1685.534 s. Mean Reward: 3.699. Std of Reward: 2.038. Training.
# [INFO] Huggy. Step: 1300000. Time Elapsed: 1756.176 s. Mean Reward: 3.803. Std of Reward: 1.947. Training.
# [INFO] Huggy. Step: 1350000. Time Elapsed: 1820.886 s. Mean Reward: 3.754. Std of Reward: 2.079. Training.
# [INFO] Huggy. Step: 1400000. Time Elapsed: 1886.451 s. Mean Reward: 3.635. Std of Reward: 2.062. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1399992.onnx
# [INFO] Huggy. Step: 1450000. Time Elapsed: 1955.039 s. Mean Reward: 3.693. Std of Reward: 2.154. Training.
# [INFO] Huggy. Step: 1500000. Time Elapsed: 2018.515 s. Mean Reward: 3.628. Std of Reward: 2.073. Training.
# [INFO] Huggy. Step: 1550000. Time Elapsed: 2086.228 s. Mean Reward: 3.711. Std of Reward: 2.076. Training.
# [INFO] Huggy. Step: 1600000. Time Elapsed: 2150.379 s. Mean Reward: 3.644. Std of Reward: 2.039. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1599352.onnx
# [INFO] Huggy. Step: 1650000. Time Elapsed: 2216.730 s. Mean Reward: 3.782. Std of Reward: 2.032. Training.
# [INFO] Huggy. Step: 1700000. Time Elapsed: 2283.696 s. Mean Reward: 3.737. Std of Reward: 2.134. Training.
# [INFO] Huggy. Step: 1750000. Time Elapsed: 2351.471 s. Mean Reward: 3.624. Std of Reward: 2.042. Training.
# [INFO] Huggy. Step: 1800000. Time Elapsed: 2422.265 s. Mean Reward: 3.646. Std of Reward: 2.069. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1799973.onnx
# [INFO] Huggy. Step: 1850000. Time Elapsed: 2486.698 s. Mean Reward: 3.543. Std of Reward: 2.185. Training.
# [INFO] Huggy. Step: 1900000. Time Elapsed: 2554.857 s. Mean Reward: 3.627. Std of Reward: 2.096. Training.
# [INFO] Huggy. Step: 1950000. Time Elapsed: 2620.737 s. Mean Reward: 3.603. Std of Reward: 2.106. Training.
# [INFO] Huggy. Step: 2000000. Time Elapsed: 2687.547 s. Mean Reward: 3.669. Std of Reward: 2.202. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1999923.onnx
# [INFO] Exported results/Huggy/Huggy/Huggy-2000026.onnx
# [INFO] Copied results/Huggy/Huggy/Huggy-2000026.onnx to results/Huggy/Huggy.onnx.

# %%
from huggingface_hub import notebook_login
notebook_login()

# !huggingface-cli login --token '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'
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !mlagents-push-to-hf --run-id="HuggyTraining" --local-dir="./results/Huggy" --repo-id="Weiming1122/ppo-Huggy" --commit-message="Huggy"
# Out:
# [INFO] This function will create a model card and upload your HuggyTraining into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo HuggyTraining to the Hugging Face Hub
# Huggy-1399992.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
# Upload 25 LFS files:   0% 0/25 [00:00<?, ?it/s]
#
# Huggy-1199259.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
# Huggy-1599352.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
#
# Huggy-1399992.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
#
#
# Huggy-1399992.pt:   0% 16.4k/13.5M [00:00<07:16, 30.9kB/s]
#
# Huggy-1199259.onnx:   1% 16.4k/2.27M [00:00<01:17, 29.2kB/s]
#
#
#
#
# Huggy-1199259.pt:   0% 16.4k/13.5M [00:00<07:37, 29.5kB/s]
#
#
# Huggy-1599352.onnx:   1% 16.4k/2.27M [00:00<01:18, 28.8kB/s]
#
#
#
# Huggy-1399992.pt:  49% 6.55M/13.5M [00:00<00:00, 13.8MB/s]
#
# Huggy-1199259.onnx:  71% 1.62M/2.27M [00:00<00:00, 3.18MB/s]
#
#
# Huggy-1599352.onnx:  38% 868k/2.27M [00:00<00:00, 1.71MB/s]
#
#
#
#
# Huggy-1199259.pt:  16% 2.10M/13.5M [00:00<00:02, 3.87MB/s]
#
#
#
# Huggy-1399992.onnx:  44% 999k/2.27M [00:00<00:00, 1.84MB/s]
#
#
# Huggy-1599352.onnx: 100% 2.27M/2.27M [00:00<00:00, 4.30MB/s]
#
#
#
#
# Huggy-1599352.onnx: 100% 2.27M/2.27M [00:00<00:00, 2.54MB/s]
# Huggy-1199259.onnx: 100% 2.27M/2.27M [00:00<00:00, 2.44MB/s]
#
#
#
#
#
# Huggy-1399992.onnx: 100% 2.27M/2.27M [00:00<00:00, 2.33MB/s]
# Huggy-1399992.pt: 100% 13.5M/13.5M [00:00<00:00, 13.6MB/s]
# Huggy-1599352.pt:  20% 2.74M/13.5M [00:00<00:00, 24.5MB/s]
# Upload 25 LFS files:   4% 1/25 [00:01<00:33,  1.39s/it]
#
# Huggy-1799973.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
# Huggy-1799973.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
#
# Huggy-1199259.pt: 100% 13.5M/13.5M [00:01<00:00, 9.41MB/s]
# Huggy-1599352.pt:  47% 6.36M/13.5M [00:00<00:00, 28.7MB/s]
#
#
# Huggy-1799973.onnx: 100% 2.27M/2.27M [00:00<00:00, 12.1MB/s]
#
#
#
# Huggy-1799973.pt:  48% 6.49M/13.5M [00:00<00:00, 30.2MB/s]
#
# Huggy-199930.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
# Upload 25 LFS files:   8% 2/25 [00:01<00:17,  1.33it/s]
#
#
#
#
# Huggy-199930.onnx: 100% 2.27M/2.27M [00:00<00:00, 7.05MB/s]
#
#
#
# Huggy-1799973.pt:  94% 12.7M/13.5M [00:00<00:00, 40.8MB/s]
#
# Huggy-1599352.pt: 100% 13.5M/13.5M [00:00<00:00, 24.5MB/s]
# Huggy-1999923.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
# Huggy-1999923.onnx: 100% 2.27M/2.27M [00:00<00:00, 12.2MB/s]
#
# Upload 25 LFS files:  24% 6/25 [00:01<00:03,  4.79it/s]
#
#
#
# Huggy-1999923.pt:  74% 10.0M/13.5M [00:00<00:00, 83.3MB/s]
#
#
#
#
# Huggy-1799973.pt: 100% 13.5M/13.5M [00:00<00:00, 23.1MB/s]
#
#
#
#
#
# Huggy.onnx: 100% 2.27M/2.27M [00:00<00:00, 10.9MB/s]
#
# Upload 25 LFS files:  32% 8/25 [00:02<00:02,  5.70it/s]
#
#
# Huggy-399939.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
#
# Huggy-399939.onnx: 100% 2.27M/2.27M [00:00<00:00, 14.0MB/s]
#
#
#
#
# Huggy-2000026.pt: 100% 13.5M/13.5M [00:00<00:00, 36.7MB/s]
#
#
#
# Huggy-599930.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
#
#
# Huggy-1999923.pt: 100% 13.5M/13.5M [00:00<00:00, 21.6MB/s]
#
#
#
#
#
# Huggy-599930.onnx: 100% 2.27M/2.27M [00:00<00:00, 12.4MB/s]
#
#
#
# Huggy-399939.pt: 100% 13.5M/13.5M [00:00<00:00, 33.0MB/s]
# Huggy-199930.pt: 100% 13.5M/13.5M [00:00<00:00, 13.6MB/s]
#
#
# Huggy-999975.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
# Huggy-599930.pt: 100% 13.5M/13.5M [00:00<00:00, 33.3MB/s]
# Huggy-799940.onnx: 100% 2.27M/2.27M [00:00<00:00, 7.50MB/s]
# Huggy-999975.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
# Upload 25 LFS files:  40% 10/25 [00:02<00:03,  3.96it/s]
#
#
#
# checkpoint.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
#
#
# Huggy-999975.onnx: 100% 2.27M/2.27M [00:00<00:00, 9.29MB/s]
# Huggy-999975.pt:  60% 8.04M/13.5M [00:00<00:00, 76.3MB/s]
#
#
#
# checkpoint.pt:  43% 5.83M/13.5M [00:00<00:00, 57.3MB/s]
#
# Huggy-799940.pt: 100% 13.5M/13.5M [00:00<00:00, 32.5MB/s]
#
# Upload 25 LFS files:  80% 20/25 [00:03<00:00, 11.44it/s]
#
#
#
# events.out.tfevents.1702534890.e03452c1cc07.14047.0: 100% 397k/397k [00:00<00:00, 1.56MB/s]
# Huggy-999975.pt: 100% 13.5M/13.5M [00:00<00:00, 37.8MB/s]
# Huggy.onnx: 100% 2.27M/2.27M [00:00<00:00, 8.99MB/s]
# checkpoint.pt: 100% 13.5M/13.5M [00:00<00:00, 17.5MB/s]
#
# Upload 25 LFS files: 100% 25/25 [00:03<00:00,  6.65it/s]
# [INFO] Your model is pushed to the hub. You can view your model here: https://huggingface.co/Weiming1122/ppo-Huggy
