# %%
# For now we install this update of RL-Baselines3 Zoo
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo (to revision update/hf) to /tmp/pip-req-build-0t8xijpa
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-0t8xijpa
#   Running command git checkout -b update/hf --track origin/update/hf
#   Switched to a new branch 'update/hf'
#   Branch 'update/hf' set up to track remote branch 'update/hf' from 'origin'.
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit 7dcbff7e74e7a12c052452181ff353a4dbed313a
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3-contrib>=2.0.0a9 (from rl-zoo3==2.0.0a9)
#   Downloading sb3_contrib-2.2.1-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 1.7 MB/s eta 0:00:00
# Collecting gym==0.26.2 (from rl-zoo3==2.0.0a9)
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 10.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting huggingface-sb3>=2.2.1 (from rl-zoo3==2.0.0a9)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from rl-zoo3==2.0.0a9) (4.66.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from rl-zoo3==2.0.0a9) (13.7.0)
# Collecting optuna (from rl-zoo3==2.0.0a9)
#   Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 31.4 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from rl-zoo3==2.0.0a9) (6.0.1)
# Collecting pytablewriter~=0.64 (from rl-zoo3==2.0.0a9)
#   Downloading pytablewriter-0.64.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (0.0.8)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (0.19.4)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (1.1.2)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter~=0.64->rl-zoo3==2.0.0a9) (67.7.2)
# Collecting DataProperty<2,>=0.55.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Collecting pathvalidate<3,>=2.3.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading pathvalidate-2.5.2-py3-none-any.whl (20 kB)
# Collecting tabledata<2,>=1.3.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading tabledata-1.3.3-py3-none-any.whl (11 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading tcolorpy-0.1.4-py3-none-any.whl (7.9 kB)
# Collecting typepy[datetime]<2,>=1.2.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading typepy-1.3.2-py3-none-any.whl (31 kB)
# Collecting stable-baselines3<3.0,>=2.2.1 (from sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9)
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 22.4 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna->rl-zoo3==2.0.0a9)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 26.2 MB/s eta 0:00:00
# Collecting colorlog (from optuna->rl-zoo3==2.0.0a9)
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna->rl-zoo3==2.0.0a9) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna->rl-zoo3==2.0.0a9) (2.0.23)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->rl-zoo3==2.0.0a9) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->rl-zoo3==2.0.0a9) (2.16.1)
# Collecting Mako (from alembic>=1.5.0->optuna->rl-zoo3==2.0.0a9)
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna->rl-zoo3==2.0.0a9) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2.31.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->rl-zoo3==2.0.0a9) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (5.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna->rl-zoo3==2.0.0a9) (3.0.2)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 42.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2.1.0+cu121)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.7.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (2023.3.post1)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2.1.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna->rl-zoo3==2.0.0a9) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.3.0)
# Building wheels for collected packages: rl-zoo3, gym
#   Building wheel for rl-zoo3 (pyproject.toml) ... done
#   Created wheel for rl-zoo3: filename=rl_zoo3-2.0.0a9-py3-none-any.whl size=76402 sha256=532744f09e347e7c02d2564383c65b48bb0082ca2680923caa6785c373329e13
#   Stored in directory: /tmp/pip-ephem-wheel-cache-efbpmkzn/wheels/fc/36/d5/2ef574649d85327de098075c8523da50be2612f3e5807261f7
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827618 sha256=32004e279cf30a6a2c657878556a3bec52a3257705929d1fd976157a5d9f3e06
#   Stored in directory: /root/.cache/pip/wheels/b9/22/6d/3e7b32d98451b4cd9d12417052affbeeeea012955d437da1da
# Successfully built rl-zoo3 gym
# Installing collected packages: farama-notifications, tcolorpy, pathvalidate, mbstrdecoder, Mako, gymnasium, gym, colorlog, typepy, alembic, stable-baselines3, optuna, huggingface-sb3, sb3-contrib, DataProperty, tabledata, pytablewriter, rl-zoo3
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.0.6 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# Successfully installed DataProperty-1.0.1 Mako-1.3.0 alembic-1.13.1 colorlog-6.8.0 farama-notifications-0.0.4 gym-0.26.2 gymnasium-0.29.1 huggingface-sb3-3.0 mbstrdecoder-1.1.3 optuna-3.5.0 pathvalidate-2.5.2 pytablewriter-0.64.2 rl-zoo3-2.0.0a9 sb3-contrib-2.2.1 stable-baselines3-2.2.1 tabledata-1.3.3 tcolorpy-0.1.4 typepy-1.3.2

# %%
#!pip install rl_zoo3==2.0.0a9

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 24 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 2s (612 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121658 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (0.0.4)
# Collecting shimmy[atari]<1.0,>=0.1.0 (from gymnasium[atari])
#   Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Collecting ale-py~=0.8.1 (from shimmy[atari]<1.0,>=0.1.0->gymnasium[atari])
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.3 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]<1.0,>=0.1.0->gymnasium[atari]) (6.1.1)
# Installing collected packages: ale-py, shimmy
# Successfully installed ale-py-0.8.1 shimmy-0.2.1
# Requirement already satisfied: gymnasium[accept-rom-license] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (0.0.4)
# Collecting autorom[accept-rom-license]~=0.4.2 (from gymnasium[accept-rom-license])
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (4.66.1)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 8.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2023.11.17)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=6ed4a132790a1af26d96ce0a128e0d8e5d8f7fa19b4e4eefd557eba5e614a011
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.4.2

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# | rollout/            |          |
# |    ep_len_mean      | 2.99e+03 |
# |    ep_rew_mean      | 354      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2716     |
# |    fps              | 240      |
# |    time_elapsed     | 2285     |
# |    total_timesteps  | 550104   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0401   |
# |    n_updates        | 112525   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.96e+03 |
# |    ep_rew_mean      | 348      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2720     |
# |    fps              | 240      |
# |    time_elapsed     | 2291     |
# |    total_timesteps  | 551562   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0657   |
# |    n_updates        | 112890   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.98e+03 |
# |    ep_rew_mean      | 348      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2724     |
# |    fps              | 240      |
# |    time_elapsed     | 2295     |
# |    total_timesteps  | 552451   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0299   |
# |    n_updates        | 113112   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.99e+03 |
# |    ep_rew_mean      | 349      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2728     |
# |    fps              | 240      |
# |    time_elapsed     | 2299     |
# |    total_timesteps  | 553484   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0271   |
# |    n_updates        | 113370   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3e+03    |
# |    ep_rew_mean      | 350      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2732     |
# |    fps              | 240      |
# |    time_elapsed     | 2303     |
# |    total_timesteps  | 554470   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.027    |
# |    n_updates        | 113617   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.97e+03 |
# |    ep_rew_mean      | 348      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2736     |
# |    fps              | 240      |
# |    time_elapsed     | 2307     |
# |    total_timesteps  | 555364   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0555   |
# |    n_updates        | 113840   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.99e+03 |
# |    ep_rew_mean      | 351      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2740     |
# |    fps              | 240      |
# |    time_elapsed     | 2314     |
# |    total_timesteps  | 556985   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 114246   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.99e+03 |
# |    ep_rew_mean      | 355      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2744     |
# |    fps              | 240      |
# |    time_elapsed     | 2317     |
# |    total_timesteps  | 557850   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0535   |
# |    n_updates        | 114462   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.97e+03 |
# |    ep_rew_mean      | 354      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2748     |
# |    fps              | 240      |
# |    time_elapsed     | 2322     |
# |    total_timesteps  | 558889   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0391   |
# |    n_updates        | 114722   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.98e+03 |
# |    ep_rew_mean      | 357      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2752     |
# |    fps              | 240      |
# |    time_elapsed     | 2326     |
# |    total_timesteps  | 559870   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0304   |
# |    n_updates        | 114967   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.98e+03 |
# |    ep_rew_mean      | 358      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2756     |
# |    fps              | 240      |
# |    time_elapsed     | 2329     |
# |    total_timesteps  | 560680   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 115169   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.99e+03 |
# |    ep_rew_mean      | 357      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2760     |
# |    fps              | 240      |
# |    time_elapsed     | 2334     |
# |    total_timesteps  | 561922   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 115480   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.99e+03 |
# |    ep_rew_mean      | 359      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2764     |
# |    fps              | 240      |
# |    time_elapsed     | 2339     |
# |    total_timesteps  | 562972   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0254   |
# |    n_updates        | 115742   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.02e+03 |
# |    ep_rew_mean      | 366      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2768     |
# |    fps              | 240      |
# |    time_elapsed     | 2345     |
# |    total_timesteps  | 564453   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0546   |
# |    n_updates        | 116113   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.01e+03 |
# |    ep_rew_mean      | 367      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2772     |
# |    fps              | 240      |
# |    time_elapsed     | 2350     |
# |    total_timesteps  | 565502   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.035    |
# |    n_updates        | 116375   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.01e+03 |
# |    ep_rew_mean      | 367      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2776     |
# |    fps              | 240      |
# |    time_elapsed     | 2352     |
# |    total_timesteps  | 566055   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 116513   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3e+03    |
# |    ep_rew_mean      | 361      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2780     |
# |    fps              | 240      |
# |    time_elapsed     | 2356     |
# |    total_timesteps  | 567048   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0459   |
# |    n_updates        | 116761   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.99e+03 |
# |    ep_rew_mean      | 359      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2784     |
# |    fps              | 240      |
# |    time_elapsed     | 2359     |
# |    total_timesteps  | 567829   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 116957   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.01e+03 |
# |    ep_rew_mean      | 361      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2788     |
# |    fps              | 240      |
# |    time_elapsed     | 2367     |
# |    total_timesteps  | 569540   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0289   |
# |    n_updates        | 117384   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.99e+03 |
# |    ep_rew_mean      | 362      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2792     |
# |    fps              | 240      |
# |    time_elapsed     | 2372     |
# |    total_timesteps  | 570879   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 117719   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.01e+03 |
# |    ep_rew_mean      | 365      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2796     |
# |    fps              | 240      |
# |    time_elapsed     | 2379     |
# |    total_timesteps  | 572342   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0247   |
# |    n_updates        | 118085   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.03e+03 |
# |    ep_rew_mean      | 367      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2800     |
# |    fps              | 240      |
# |    time_elapsed     | 2384     |
# |    total_timesteps  | 573665   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0638   |
# |    n_updates        | 118416   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.03e+03 |
# |    ep_rew_mean      | 366      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2804     |
# |    fps              | 240      |
# |    time_elapsed     | 2388     |
# |    total_timesteps  | 574594   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0378   |
# |    n_updates        | 118648   |
# ----------------------------------
# Eval num_timesteps=575000, episode_reward=473.00 +/- 63.77
# Episode length: 3250.20 +/- 356.37
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.25e+03 |
# |    mean_reward      | 473      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 575000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 118749   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 367      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2808     |
# |    fps              | 239      |
# |    time_elapsed     | 2405     |
# |    total_timesteps  | 575987   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0396   |
# |    n_updates        | 118996   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 367      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2812     |
# |    fps              | 239      |
# |    time_elapsed     | 2410     |
# |    total_timesteps  | 577192   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 119297   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.02e+03 |
# |    ep_rew_mean      | 366      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2816     |
# |    fps              | 239      |
# |    time_elapsed     | 2416     |
# |    total_timesteps  | 578685   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0208   |
# |    n_updates        | 119671   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.02e+03 |
# |    ep_rew_mean      | 368      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2820     |
# |    fps              | 239      |
# |    time_elapsed     | 2423     |
# |    total_timesteps  | 580319   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0418   |
# |    n_updates        | 120079   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.01e+03 |
# |    ep_rew_mean      | 367      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2824     |
# |    fps              | 239      |
# |    time_elapsed     | 2427     |
# |    total_timesteps  | 581455   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0523   |
# |    n_updates        | 120363   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.02e+03 |
# |    ep_rew_mean      | 372      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2828     |
# |    fps              | 239      |
# |    time_elapsed     | 2431     |
# |    total_timesteps  | 582269   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0271   |
# |    n_updates        | 120567   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.03e+03 |
# |    ep_rew_mean      | 374      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2832     |
# |    fps              | 239      |
# |    time_elapsed     | 2436     |
# |    total_timesteps  | 583496   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 120873   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04e+03 |
# |    ep_rew_mean      | 378      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2836     |
# |    fps              | 239      |
# |    time_elapsed     | 2441     |
# |    total_timesteps  | 584662   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 121165   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 379      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2840     |
# |    fps              | 239      |
# |    time_elapsed     | 2445     |
# |    total_timesteps  | 585514   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 121378   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 379      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2844     |
# |    fps              | 239      |
# |    time_elapsed     | 2448     |
# |    total_timesteps  | 586287   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0214   |
# |    n_updates        | 121571   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 381      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2848     |
# |    fps              | 239      |
# |    time_elapsed     | 2451     |
# |    total_timesteps  | 587045   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.018    |
# |    n_updates        | 121761   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 383      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2852     |
# |    fps              | 239      |
# |    time_elapsed     | 2454     |
# |    total_timesteps  | 587734   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0204   |
# |    n_updates        | 121933   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2856     |
# |    fps              | 239      |
# |    time_elapsed     | 2459     |
# |    total_timesteps  | 588787   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 122196   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2860     |
# |    fps              | 239      |
# |    time_elapsed     | 2462     |
# |    total_timesteps  | 589622   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 122405   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2864     |
# |    fps              | 239      |
# |    time_elapsed     | 2467     |
# |    total_timesteps  | 590748   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0478   |
# |    n_updates        | 122686   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2868     |
# |    fps              | 239      |
# |    time_elapsed     | 2473     |
# |    total_timesteps  | 591774   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 122943   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.02e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2872     |
# |    fps              | 239      |
# |    time_elapsed     | 2477     |
# |    total_timesteps  | 592885   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 123221   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.03e+03 |
# |    ep_rew_mean      | 392      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2876     |
# |    fps              | 239      |
# |    time_elapsed     | 2483     |
# |    total_timesteps  | 594445   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0224   |
# |    n_updates        | 123611   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2880     |
# |    fps              | 239      |
# |    time_elapsed     | 2488     |
# |    total_timesteps  | 595486   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0302   |
# |    n_updates        | 123871   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 399      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2884     |
# |    fps              | 239      |
# |    time_elapsed     | 2493     |
# |    total_timesteps  | 596653   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0375   |
# |    n_updates        | 124163   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 403      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2888     |
# |    fps              | 239      |
# |    time_elapsed     | 2497     |
# |    total_timesteps  | 597651   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0182   |
# |    n_updates        | 124412   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 405      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2892     |
# |    fps              | 239      |
# |    time_elapsed     | 2502     |
# |    total_timesteps  | 598725   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00983  |
# |    n_updates        | 124681   |
# ----------------------------------
# Eval num_timesteps=600000, episode_reward=488.00 +/- 172.38
# Episode length: 3321.80 +/- 632.10
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.32e+03 |
# |    mean_reward      | 488      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 600000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0211   |
# |    n_updates        | 124999   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2896     |
# |    fps              | 238      |
# |    time_elapsed     | 2520     |
# |    total_timesteps  | 600325   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0171   |
# |    n_updates        | 125081   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 238      |
# |    time_elapsed     | 2525     |
# |    total_timesteps  | 601588   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0225   |
# |    n_updates        | 125396   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2904     |
# |    fps              | 238      |
# |    time_elapsed     | 2530     |
# |    total_timesteps  | 602889   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 125722   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2908     |
# |    fps              | 238      |
# |    time_elapsed     | 2535     |
# |    total_timesteps  | 603970   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0408   |
# |    n_updates        | 125992   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2912     |
# |    fps              | 238      |
# |    time_elapsed     | 2542     |
# |    total_timesteps  | 605730   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0305   |
# |    n_updates        | 126432   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 422      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2916     |
# |    fps              | 238      |
# |    time_elapsed     | 2545     |
# |    total_timesteps  | 606378   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0437   |
# |    n_updates        | 126594   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 420      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2920     |
# |    fps              | 238      |
# |    time_elapsed     | 2548     |
# |    total_timesteps  | 607155   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.024    |
# |    n_updates        | 126788   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 424      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2924     |
# |    fps              | 238      |
# |    time_elapsed     | 2554     |
# |    total_timesteps  | 608452   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0314   |
# |    n_updates        | 127112   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 425      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2928     |
# |    fps              | 238      |
# |    time_elapsed     | 2558     |
# |    total_timesteps  | 609400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 127349   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 420      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2932     |
# |    fps              | 238      |
# |    time_elapsed     | 2562     |
# |    total_timesteps  | 610375   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0781   |
# |    n_updates        | 127593   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 422      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2936     |
# |    fps              | 238      |
# |    time_elapsed     | 2568     |
# |    total_timesteps  | 611687   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0553   |
# |    n_updates        | 127921   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 425      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2940     |
# |    fps              | 238      |
# |    time_elapsed     | 2573     |
# |    total_timesteps  | 612895   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0251   |
# |    n_updates        | 128223   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 427      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2944     |
# |    fps              | 238      |
# |    time_elapsed     | 2579     |
# |    total_timesteps  | 614560   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 128639   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 425      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2948     |
# |    fps              | 238      |
# |    time_elapsed     | 2584     |
# |    total_timesteps  | 615585   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 128896   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 426      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2952     |
# |    fps              | 238      |
# |    time_elapsed     | 2588     |
# |    total_timesteps  | 616575   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0173   |
# |    n_updates        | 129143   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 423      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2956     |
# |    fps              | 238      |
# |    time_elapsed     | 2593     |
# |    total_timesteps  | 617778   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 129444   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 424      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2960     |
# |    fps              | 238      |
# |    time_elapsed     | 2596     |
# |    total_timesteps  | 618454   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 129613   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 424      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2964     |
# |    fps              | 238      |
# |    time_elapsed     | 2600     |
# |    total_timesteps  | 619433   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 129858   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 427      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2968     |
# |    fps              | 238      |
# |    time_elapsed     | 2606     |
# |    total_timesteps  | 620971   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 130242   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 427      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2972     |
# |    fps              | 238      |
# |    time_elapsed     | 2613     |
# |    total_timesteps  | 622388   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 130596   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 430      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2976     |
# |    fps              | 238      |
# |    time_elapsed     | 2616     |
# |    total_timesteps  | 623327   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0193   |
# |    n_updates        | 130831   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 434      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2980     |
# |    fps              | 238      |
# |    time_elapsed     | 2623     |
# |    total_timesteps  | 624773   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0333   |
# |    n_updates        | 131193   |
# ----------------------------------
# Eval num_timesteps=625000, episode_reward=411.00 +/- 174.65
# Episode length: 3044.40 +/- 957.27
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.04e+03 |
# |    mean_reward      | 411      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 625000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0274   |
# |    n_updates        | 131249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2984     |
# |    fps              | 237      |
# |    time_elapsed     | 2638     |
# |    total_timesteps  | 625957   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0213   |
# |    n_updates        | 131489   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2988     |
# |    fps              | 237      |
# |    time_elapsed     | 2642     |
# |    total_timesteps  | 626967   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 131741   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 440      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2992     |
# |    fps              | 237      |
# |    time_elapsed     | 2645     |
# |    total_timesteps  | 627924   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0388   |
# |    n_updates        | 131980   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 437      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2996     |
# |    fps              | 237      |
# |    time_elapsed     | 2651     |
# |    total_timesteps  | 628979   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.067    |
# |    n_updates        | 132244   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 439      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3000     |
# |    fps              | 237      |
# |    time_elapsed     | 2657     |
# |    total_timesteps  | 630670   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 132667   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3004     |
# |    fps              | 237      |
# |    time_elapsed     | 2660     |
# |    total_timesteps  | 631336   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 132833   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 436      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3008     |
# |    fps              | 237      |
# |    time_elapsed     | 2664     |
# |    total_timesteps  | 632073   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0367   |
# |    n_updates        | 133018   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3012     |
# |    fps              | 237      |
# |    time_elapsed     | 2668     |
# |    total_timesteps  | 633253   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0382   |
# |    n_updates        | 133313   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 439      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3016     |
# |    fps              | 237      |
# |    time_elapsed     | 2675     |
# |    total_timesteps  | 634861   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0497   |
# |    n_updates        | 133715   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 440      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3020     |
# |    fps              | 237      |
# |    time_elapsed     | 2679     |
# |    total_timesteps  | 635856   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0481   |
# |    n_updates        | 133963   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3024     |
# |    fps              | 237      |
# |    time_elapsed     | 2686     |
# |    total_timesteps  | 637520   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0843   |
# |    n_updates        | 134379   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3028     |
# |    fps              | 237      |
# |    time_elapsed     | 2690     |
# |    total_timesteps  | 638436   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 134608   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3032     |
# |    fps              | 237      |
# |    time_elapsed     | 2697     |
# |    total_timesteps  | 640109   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0252   |
# |    n_updates        | 135027   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 445      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3036     |
# |    fps              | 237      |
# |    time_elapsed     | 2701     |
# |    total_timesteps  | 641056   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00931  |
# |    n_updates        | 135263   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3040     |
# |    fps              | 237      |
# |    time_elapsed     | 2705     |
# |    total_timesteps  | 641886   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0407   |
# |    n_updates        | 135471   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 445      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3044     |
# |    fps              | 237      |
# |    time_elapsed     | 2711     |
# |    total_timesteps  | 643334   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0368   |
# |    n_updates        | 135833   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3048     |
# |    fps              | 237      |
# |    time_elapsed     | 2714     |
# |    total_timesteps  | 644089   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0378   |
# |    n_updates        | 136022   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3052     |
# |    fps              | 237      |
# |    time_elapsed     | 2719     |
# |    total_timesteps  | 645103   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0516   |
# |    n_updates        | 136275   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 441      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3056     |
# |    fps              | 237      |
# |    time_elapsed     | 2724     |
# |    total_timesteps  | 646425   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0256   |
# |    n_updates        | 136606   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3060     |
# |    fps              | 237      |
# |    time_elapsed     | 2729     |
# |    total_timesteps  | 647537   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0397   |
# |    n_updates        | 136884   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 445      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3064     |
# |    fps              | 237      |
# |    time_elapsed     | 2735     |
# |    total_timesteps  | 648861   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0299   |
# |    n_updates        | 137215   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0292   |
# |    n_updates        | 213376   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.42e+03 |
# |    ep_rew_mean      | 678      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3864     |
# |    fps              | 227      |
# |    time_elapsed     | 4214     |
# |    total_timesteps  | 957505   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0211   |
# |    n_updates        | 214376   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.43e+03 |
# |    ep_rew_mean      | 680      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3868     |
# |    fps              | 227      |
# |    time_elapsed     | 4220     |
# |    total_timesteps  | 958923   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 214730   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.45e+03 |
# |    ep_rew_mean      | 681      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3872     |
# |    fps              | 227      |
# |    time_elapsed     | 4229     |
# |    total_timesteps  | 961277   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 215319   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.42e+03 |
# |    ep_rew_mean      | 681      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3876     |
# |    fps              | 227      |
# |    time_elapsed     | 4235     |
# |    total_timesteps  | 962561   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0324   |
# |    n_updates        | 215640   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.42e+03 |
# |    ep_rew_mean      | 680      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3880     |
# |    fps              | 227      |
# |    time_elapsed     | 4241     |
# |    total_timesteps  | 964099   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0463   |
# |    n_updates        | 216024   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.38e+03 |
# |    ep_rew_mean      | 672      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3884     |
# |    fps              | 227      |
# |    time_elapsed     | 4246     |
# |    total_timesteps  | 965266   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 216316   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.39e+03 |
# |    ep_rew_mean      | 672      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3888     |
# |    fps              | 227      |
# |    time_elapsed     | 4253     |
# |    total_timesteps  | 966815   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 216703   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.36e+03 |
# |    ep_rew_mean      | 668      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3892     |
# |    fps              | 227      |
# |    time_elapsed     | 4262     |
# |    total_timesteps  | 968770   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 217192   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.33e+03 |
# |    ep_rew_mean      | 664      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3896     |
# |    fps              | 227      |
# |    time_elapsed     | 4264     |
# |    total_timesteps  | 969450   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0304   |
# |    n_updates        | 217362   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.32e+03 |
# |    ep_rew_mean      | 662      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3900     |
# |    fps              | 227      |
# |    time_elapsed     | 4274     |
# |    total_timesteps  | 971707   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0139   |
# |    n_updates        | 217926   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.32e+03 |
# |    ep_rew_mean      | 660      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3904     |
# |    fps              | 227      |
# |    time_elapsed     | 4280     |
# |    total_timesteps  | 973333   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.123    |
# |    n_updates        | 218333   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.3e+03  |
# |    ep_rew_mean      | 658      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3908     |
# |    fps              | 227      |
# |    time_elapsed     | 4286     |
# |    total_timesteps  | 974719   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00866  |
# |    n_updates        | 218679   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=556.00 +/- 129.44
# Episode length: 4585.20 +/- 375.97
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.59e+03 |
# |    mean_reward      | 556      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.25e+03 |
# |    ep_rew_mean      | 660      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3912     |
# |    fps              | 226      |
# |    time_elapsed     | 4311     |
# |    total_timesteps  | 977068   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0461   |
# |    n_updates        | 219266   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.3e+03  |
# |    ep_rew_mean      | 669      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3916     |
# |    fps              | 226      |
# |    time_elapsed     | 4320     |
# |    total_timesteps  | 979148   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0291   |
# |    n_updates        | 219786   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.31e+03 |
# |    ep_rew_mean      | 671      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3920     |
# |    fps              | 226      |
# |    time_elapsed     | 4326     |
# |    total_timesteps  | 980625   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0174   |
# |    n_updates        | 220156   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.3e+03  |
# |    ep_rew_mean      | 674      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3924     |
# |    fps              | 226      |
# |    time_elapsed     | 4331     |
# |    total_timesteps  | 981701   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0844   |
# |    n_updates        | 220425   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.28e+03 |
# |    ep_rew_mean      | 670      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3928     |
# |    fps              | 226      |
# |    time_elapsed     | 4338     |
# |    total_timesteps  | 983497   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.026    |
# |    n_updates        | 220874   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.28e+03 |
# |    ep_rew_mean      | 672      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3932     |
# |    fps              | 226      |
# |    time_elapsed     | 4343     |
# |    total_timesteps  | 984729   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 221182   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.24e+03 |
# |    ep_rew_mean      | 667      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3936     |
# |    fps              | 226      |
# |    time_elapsed     | 4348     |
# |    total_timesteps  | 985948   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0266   |
# |    n_updates        | 221486   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.25e+03 |
# |    ep_rew_mean      | 671      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3940     |
# |    fps              | 226      |
# |    time_elapsed     | 4357     |
# |    total_timesteps  | 988076   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 222018   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21e+03 |
# |    ep_rew_mean      | 666      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3944     |
# |    fps              | 226      |
# |    time_elapsed     | 4365     |
# |    total_timesteps  | 989980   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0314   |
# |    n_updates        | 222494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21e+03 |
# |    ep_rew_mean      | 666      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3948     |
# |    fps              | 226      |
# |    time_elapsed     | 4371     |
# |    total_timesteps  | 991192   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0861   |
# |    n_updates        | 222797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.19e+03 |
# |    ep_rew_mean      | 661      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3952     |
# |    fps              | 226      |
# |    time_elapsed     | 4377     |
# |    total_timesteps  | 992823   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 223205   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18e+03 |
# |    ep_rew_mean      | 657      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3956     |
# |    fps              | 226      |
# |    time_elapsed     | 4384     |
# |    total_timesteps  | 994339   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0407   |
# |    n_updates        | 223584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16e+03 |
# |    ep_rew_mean      | 652      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3960     |
# |    fps              | 226      |
# |    time_elapsed     | 4389     |
# |    total_timesteps  | 995656   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0292   |
# |    n_updates        | 223913   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13e+03 |
# |    ep_rew_mean      | 647      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3964     |
# |    fps              | 226      |
# |    time_elapsed     | 4396     |
# |    total_timesteps  | 997244   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0241   |
# |    n_updates        | 224310   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13e+03 |
# |    ep_rew_mean      | 648      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3968     |
# |    fps              | 226      |
# |    time_elapsed     | 4403     |
# |    total_timesteps  | 998965   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0311   |
# |    n_updates        | 224741   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13e+03 |
# |    ep_rew_mean      | 651      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3972     |
# |    fps              | 226      |
# |    time_elapsed     | 4407     |
# |    total_timesteps  | 999995   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.046    |
# |    n_updates        | 224998   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=454.00 +/- 154.51
# Episode length: 3962.60 +/- 1059.44
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.96e+03 |
# |    mean_reward      | 454      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_1

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# 2023-12-21 04:50:29.332730: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 04:50:29.332780: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 04:50:29.334218: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 04:50:29.342190: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-21 04:50:30.543316: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 705.00
# Atari Episode Length 4781
# Atari Episode Score: 265.00
# Atari Episode Length 2595
# Atari Episode Score: 545.00
# Atari Episode Length 4337
# Atari Episode Score: 605.00
# Atari Episode Length 4456
# Atari Episode Score: 465.00
# Atari Episode Length 3869

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store

# !huggingface-cli login --token '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'
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga Weiming1122  -f logs/
# Out:
# 2023-12-21 05:05:31.487746: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 05:05:31.487808: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 05:05:31.489919: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 05:05:31.501730: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-21 05:05:33.270108: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to Weiming1122/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:127: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# Cloning https://huggingface.co/Weiming1122/dqn-SpaceInvadersNoFrameskip-v4 into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/Weiming1122/dqn-SpaceInvadersNoFrameskip-v4 into local empty directory.
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:335: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# Saving video to /tmp/tmpqvif5acy/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmpqvif5acy/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpqvif5acy/-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpqvif5acy/-step-0-to-step-1000.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmpqvif5acy/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.40, start: 0.000000, bitrate: 53 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 160x210, 51 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5ba06201e340] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5ba06201e340] profile High, level 1.2, 4:2:0, 8-bit
# [libx264 @ 0x5ba06201e340] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'hub/dqn-SpaceInvadersNoFrameskip-v4/replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 160x210, q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame= 1002 fps=967 q=-1.0 Lsize=     216kB time=00:00:33.30 bitrate=  53.1kbits/s speed=32.1x
# video:205kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.108933%
# [libx264 @ 0x5ba06201e340] frame I:5     Avg QP:17.28  size:  2711
# [libx264 @ 0x5ba06201e340] frame P:545   Avg QP:22.41  size:   313
# [libx264 @ 0x5ba06201e340] frame B:452   Avg QP:29.17  size:    56
# [libx264 @ 0x5ba06201e340] consecutive B-frames: 34.7% 12.4%  9.0% 43.9%
# [libx264 @ 0x5ba06201e340] mb I  I16..4: 22.1% 39.6% 38.3%
# [libx264 @ 0x5ba06201e340] mb P  I16..4:  0.6%  1.0%  0.8%  P16..4:  8.1%  2.7%  1.4%  0.0%  0.0%    skip:85.3%
# [libx264 @ 0x5ba06201e340] mb B  I16..4:  0.2%  0.1%  0.1%  B16..8: 10.7%  1.1%  0.1%  direct: 0.1%  skip:87.6%  L0:46.3% L1:53.2% BI: 0.5%
# [libx264 @ 0x5ba06201e340] 8x8 transform intra:40.2% inter:5.7%
# [libx264 @ 0x5ba06201e340] coded y,uvDC,uvAC intra: 19.7% 36.8% 33.1% inter: 1.4% 1.8% 1.5%
# [libx264 @ 0x5ba06201e340] i16 v,h,dc,p: 46% 48%  6%  0%
# [libx264 @ 0x5ba06201e340] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25%  7% 66%  1%  0%  0%  0%  0%  0%
# [libx264 @ 0x5ba06201e340] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 12% 42%  2%  2%  2%  1%  2%  1%
# [libx264 @ 0x5ba06201e340] i8c dc,h,v,p: 53% 31% 15%  1%
# [libx264 @ 0x5ba06201e340] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5ba06201e340] ref P L0: 78.1%  4.4%  9.7%  7.8%
# [libx264 @ 0x5ba06201e340] ref B L0: 84.1% 12.4%  3.4%
# [libx264 @ 0x5ba06201e340] ref B L1: 95.4%  4.6%
# [libx264 @ 0x5ba06201e340] kb/s:50.19
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:   0% 1.00/26.0M [00:00<?, ?B/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth:   0% 1.00/864 [00:00<?, ?B/s]
#
# Upload file train_eval_metrics.zip:   0% 1.00/36.3k [00:00<?, ?B/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   0% 1.00/12.9M [00:00<?, ?B/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   0% 1.00/12.9M [00:00<?, ?B/s]
#
#
#
#
# Upload file replay.mp4:   0% 1.00/216k [00:00<?, ?B/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  59% 15.3M/26.0M [00:03<00:02, 5.33MB/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 15.3MB [00:02, 7.99MB/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 15.3MB [00:02, 7.99MB/s]       To https://huggingface.co/Weiming1122/dqn-SpaceInvadersNoFrameskip-v4
#    25ed915..556cf18  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/Weiming1122/dqn-SpaceInvadersNoFrameskip-v4
#    25ed915..556cf18  main -> main
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 100% 26.0M/26.0M [00:06<00:00, 4.53MB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100% 864/864 [00:05<00:00, 3.20MB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100% 864/864 [00:05<00:00, 172B/s]
#
#
# Upload file train_eval_metrics.zip: 100% 36.3k/36.3k [00:05<00:00, 3.20MB/s]
#
# Upload file train_eval_metrics.zip: 100% 36.3k/36.3k [00:05<00:00, 7.43kB/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100% 12.9M/12.9M [00:05<00:00, 2.70MB/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100% 12.9M/12.9M [00:05<00:00, 2.70MB/s]
#
#
#
#
#
# Upload file replay.mp4: 100% 216k/216k [00:05<00:00, 44.1kB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/Weiming1122/dqn-SpaceInvadersNoFrameskip-v4

# %%
# Download model and save it into the rl_trained folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/
# Out:
# 2023-12-21 05:21:10.943437: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 05:21:10.943489: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 05:21:10.944849: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 05:21:10.952368: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-21 05:21:12.221498: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading from https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# dqn-BeamRiderNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:00<00:00, 264MB/s]
# config.yml: 100% 548/548 [00:00<00:00, 2.75MB/s]
# No normalization file
# args.yml: 100% 887/887 [00:00<00:00, 4.39MB/s]
# env_kwargs.yml: 100% 3.00/3.00 [00:00<00:00, 15.7kB/s]
# train_eval_metrics.zip: 100% 244k/244k [00:00<00:00, 221MB/s]
# Saving to rl_trained/dqn/BeamRiderNoFrameskip-v4_1

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render
# Out:
# 2023-12-21 05:21:31.933407: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 05:21:31.933462: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 05:21:31.934894: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 05:21:31.942207: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-21 05:21:33.172137: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading rl_trained/dqn/BeamRiderNoFrameskip-v4_1/BeamRiderNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/save_util.py:166: UserWarning: Could not deserialize object exploration_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: 'bytes' object cannot be interpreted as an integer
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(
# Atari Episode Score: 3028.00
# Atari Episode Length 14816
