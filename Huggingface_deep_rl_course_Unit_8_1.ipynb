# %%
# !pip install setuptools==65.5.0
# Out:
# Requirement already satisfied: setuptools==65.5.0 in /usr/local/lib/python3.10/dist-packages (65.5.0)

# %%
# %%capture
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !apt install swig cmake
# !pip install pyglet==1.5
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# !pip install gym==0.22
# !pip install imageio-ffmpeg
# !pip install huggingface_hub
# !pip install gym[box2d]==0.22
# Out:
# Collecting gym==0.22
#   Downloading gym-0.22.0.tar.gz (631 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 7.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.22) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.22) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym==0.22) (0.0.8)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.22.0-py3-none-any.whl size=708363 sha256=2d65ea6b4ef6a47ce413f5f67682a952db90e294fdd365442b2ee7c4d43a4070
#   Stored in directory: /root/.cache/pip/wheels/42/e8/e8/6dfbc92a1dcd76c1a5e2bb982750fd6b7e792239f46039e6b1
# Successfully built gym
# Installing collected packages: gym
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# Successfully installed gym-0.22.0
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.10/dist-packages (0.4.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg) (65.5.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.20.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.11.17)
# Requirement already satisfied: gym[box2d]==0.22 in /usr/local/lib/python3.10/dist-packages (0.22.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]==0.22) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]==0.22) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]==0.22) (0.0.8)
# Collecting box2d-py==2.3.5 (from gym[box2d]==0.22)
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pygame==2.1.0 (from gym[box2d]==0.22)
#   Downloading pygame-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 49.3 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2349148 sha256=114dbcc38610c38c202292f3dd7f69ee4d9376d6e41e5a8794f9e17d3eaa1079
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: box2d-py, pygame
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.5.2
#     Uninstalling pygame-2.5.2:
#       Successfully uninstalled pygame-2.5.2
# Successfully installed box2d-py-2.3.5 pygame-2.1.0

# %%
from huggingface_hub import notebook_login
notebook_login()
# !git config --global credential.helper store

# !huggingface-cli login --token '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'
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# ppo.py

import argparse
import os
import random
import time
from distutils.util import strtobool

import gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions.categorical import Categorical
from torch.utils.tensorboard import SummaryWriter

from huggingface_hub import HfApi, upload_folder
from huggingface_hub.repocard import metadata_eval_result, metadata_save

from pathlib import Path
import datetime
import tempfile
import json
import shutil
import imageio

from wasabi import Printer
msg = Printer()

def parse_args():
  # fmt: off
  parser = argparse.ArgumentParser()
  parser.add_argument("--exp-name", type=str, default=os.path.basename(__file__).rstrip(".py"),
    help="the name of this experiment")
  parser.add_argument("--seed", type=int, default=1,
    help="seed of the experiment")
  parser.add_argument("--torch-deterministic", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
    help="if toggled, `torch.backends.cudnn.deterministic=False`")
  parser.add_argument("--cuda", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
    help="if toggled, cuda will be enabled by default")
  parser.add_argument("--track", type=lambda x: bool(strtobool(x)), default=False, nargs="?", const=True,
    help="if toggled, this experiment will be tracked with Weights and Biases")
  parser.add_argument("--wandb-project-name", type=str, default="cleanRL",
    help="the wandb's project name")
  parser.add_argument("--wandb-entity", type=str, default=None,
    help="the entity (team) of wandb's project")
  parser.add_argument("--capture-video", type=lambda x: bool(strtobool(x)), default=False, nargs="?", const=True,
    help="weather to capture videos of the agent performances (check out `videos` folder)")

  # Algorithm specific arguments
  parser.add_argument("--env-id", type=str, default="LunarLander-v2",
    help="the id of the environment")
  parser.add_argument("--total-timesteps", type=int, default=1000000,
    help="total timesteps of the experiments")
  parser.add_argument("--learning-rate", type=float, default=3e-4,
    help="the learning rate of the optimizer")
  parser.add_argument("--num-envs", type=int, default=16,
    help="the number of parallel game environments")
  parser.add_argument("--num-steps", type=int, default=2048,
    help="the number of steps to run in each environment per policy rollout")
  parser.add_argument("--anneal-lr", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
    help="Toggle learning rate annealing for policy and value networks")
  parser.add_argument("--gae", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
    help="Use GAE for advantage computation")
  parser.add_argument("--gamma", type=float, default=0.999,
    help="the discount factor gamma")
  parser.add_argument("--gae-lambda", type=float, default=0.98,
    help="the lambda for the general advantage estimation")
  parser.add_argument("--num-minibatches", type=int, default=4,
    help="the number of mini-batches")
  parser.add_argument("--update-epochs", type=int, default=10,
    help="the K epochs to update the policy")
  parser.add_argument("--norm-adv", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
    help="Toggles advantages normalization")
  parser.add_argument("--clip-coef", type=float, default=0.2,
    help="the surrogate clipping coefficient")
  parser.add_argument("--clip-vloss", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
    help="Toggles whether or not to use a clipped loss for the value function, as per the paper.")
  parser.add_argument("--ent-coef", type=float, default=0.01,
    help="coefficient of the entropy")
  parser.add_argument("--vf-coef", type=float, default=0.5,
    help="coefficient of the value function")
  parser.add_argument("--max-grad-norm", type=float, default=0.5,
    help="the maximum norm for the gradient clipping")
  parser.add_argument("--target-kl", type=float, default=None,
    help="the target KL divergence threshold")

  # Adding HuggingFace argument
  parser.add_argument("--repo-id", type=str, default="Weiming1122/ppo-CartPole-v1", help="id of the model repository from the Hugging Face Hub {username/repo_name}")

  args = parser.parse_args()
  args.batch_size = int(args.num_envs * args.num_steps)
  args.minibatch_size = int(args.batch_size // args.num_minibatches)
  # fmt: on
  return args

def package_to_hub(repo_id,
          model,
          hyperparameters,
          eval_env,
          video_fps=30,
          commit_message="Push agent to the Hub",
          token= None,
          logs=None
          ):
  """
  Evaluate, Generate a video and Upload a model to Hugging Face Hub.
  This method does the complete pipeline:
  - It evaluates the model
  - It generates the model card
  - It generates a replay video of the agent
  - It pushes everything to the hub
  :param repo_id: id of the model repository from the Hugging Face Hub
  :param model: trained model
  :param eval_env: environment used to evaluate the agent
  :param fps: number of fps for rendering the video
  :param commit_message: commit message
  :param logs: directory on local machine of tensorboard logs you'd like to upload
  """
  msg.info(
      "This function will save, evaluate, generate a video of your agent, "
      "create a model card and push everything to the hub. "
      "It might take up to 1min. \n "
      "This is a work in progress: if you encounter a bug, please open an issue."
      )
  # Step 1: Clone or create the repo
  repo_url = HfApi().create_repo(
                  repo_id=repo_id,
                  token=token,
                  private=False,
                  exist_ok=True,
                  )

  with tempfile.TemporaryDirectory() as tmpdirname:
    tmpdirname = Path(tmpdirname)

    # Step 2: Save the model
    torch.save(model.state_dict(), tmpdirname / "model.pt")

    # Step 3: Evaluate the model and build JSON
    mean_reward, std_reward = _evaluate_agent(eval_env,
                          10,
                          model
                          )

    # First get datetime
    eval_datetime = datetime.datetime.now()
    eval_form_datetime = eval_datetime.isoformat()

    evaluate_data = {
            "env_id": hyperparameters.env_id,
            "mean_reward": mean_reward,
            "std_reward": std_reward,
            "n_evaluation_episodes": 10,
            "eval_datetime": eval_form_datetime,
            }

    # Write a JSON file
    with open(tmpdirname / "results.json", "w") as outfile:
      json.dump(evaluate_data, outfile)

    # Step 4: Generate a video
    video_path =  tmpdirname / "replay.mp4"
    record_video(eval_env, model, video_path, video_fps)

    # Step 5: Generate the model card
    generated_model_card, metadata = _generate_model_card("PPO", hyperparameters.env_id, mean_reward, std_reward, hyperparameters)
    _save_model_card(tmpdirname, generated_model_card, metadata)

    # Step 6: Add logs if needed
    if logs:
      _add_logdir(tmpdirname, Path(logs))

    msg.info(f"Pushing repo {repo_id} to the Hugging Face Hub")

    repo_url = upload_folder(
                repo_id=repo_id,
                folder_path=tmpdirname,
                path_in_repo="",
                commit_message=commit_message,
                token=token,
                )

    msg.info(f"Your model is pushed to the Hub. You can view your model here: {repo_url}")
  return repo_url


def _evaluate_agent(env, n_eval_episodes, policy):
  """
  Evaluate the agent for ``n_eval_episodes`` episodes and returns average reward and std of reward.
  :param env: The evaluation environment
  :param n_eval_episodes: Number of episode to evaluate the agent
  :param policy: The agent
  """
  episode_rewards = []
  for episode in range(n_eval_episodes):
    state = env.reset()
    step = 0
    done = False
    total_rewards_ep = 0

    while done is False:
      state = torch.Tensor(state).to(device)
      action, _, _, _ = policy.get_action_and_value(state)
      new_state, reward, done, info = env.step(action.cpu().numpy())
      total_rewards_ep += reward
      if done:
        break
      state = new_state
    episode_rewards.append(total_rewards_ep)
  mean_reward = np.mean(episode_rewards)
  std_reward = np.std(episode_rewards)

  return mean_reward, std_reward


def record_video(env, policy, out_directory, fps=30):
  images = []
  done = False
  state = env.reset()
  img = env.render(mode='rgb_array')
  images.append(img)
  while not done:
    state = torch.Tensor(state).to(device)
    # Take the action (index) that have the maximum expected future reward given that state
    action, _, _, _  = policy.get_action_and_value(state)
    state, reward, done, info = env.step(action.cpu().numpy()) # We directly put next_state = state for recording logic
    img = env.render(mode='rgb_array')
    images.append(img)
  imageio.mimsave(out_directory, [np.array(img) for i, img in enumerate(images)], fps=fps)


def _generate_model_card(model_name, env_id, mean_reward, std_reward, hyperparameters):
  """
  Generate the model card for the Hub
  :param model_name: name of the model
  :env_id: name of the environment
  :mean_reward: mean reward of the agent
  :std_reward: standard deviation of the mean reward of the agent
  :hyperparameters: training arguments
  """
  # Step 1: Select the tags
  metadata = generate_metadata(model_name, env_id, mean_reward, std_reward)

  # Transform the hyperparams namespace to string
  converted_dict = vars(hyperparameters)
  converted_str = str(converted_dict)
  converted_str = converted_str.split(", ")
  converted_str = '\n'.join(converted_str)

  # Step 2: Generate the model card
  model_card = f"""
  # PPO Agent Playing {env_id}

  This is a trained model of a PPO agent playing {env_id}.

  # Hyperparameters
  ```python
  {converted_str}
  ```
  """
  return model_card, metadata


def generate_metadata(model_name, env_id, mean_reward, std_reward):
  """
  Define the tags for the model card
  :param model_name: name of the model
  :param env_id: name of the environment
  :mean_reward: mean reward of the agent
  :std_reward: standard deviation of the mean reward of the agent
  """
  metadata = {}
  metadata["tags"] = [
            env_id,
            "ppo",
            "deep-reinforcement-learning",
            "reinforcement-learning",
            "custom-implementation",
            "deep-rl-course"
            ]

  # Add metrics
  eval = metadata_eval_result(
                model_pretty_name=model_name,
                task_pretty_name="reinforcement-learning",
                task_id="reinforcement-learning",
                metrics_pretty_name="mean_reward",
                metrics_id="mean_reward",
                metrics_value=f"{mean_reward:.2f} +/- {std_reward:.2f}",
                dataset_pretty_name=env_id,
                dataset_id=env_id,
                )

  # Merges both dictionaries
  metadata = {**metadata, **eval}

  return metadata


def _save_model_card(local_path, generated_model_card, metadata):
    """Saves a model card for the repository.
    :param local_path: repository directory
    :param generated_model_card: model card generated by _generate_model_card()
    :param metadata: metadata
    """
    readme_path = local_path / "README.md"
    readme = ""
    if readme_path.exists():
      with readme_path.open("r", encoding="utf8") as f:
        readme = f.read()
    else:
      readme = generated_model_card

    with readme_path.open("w", encoding="utf-8") as f:
      f.write(readme)

    # Save our metrics to Readme metadata
    metadata_save(readme_path, metadata)


def _add_logdir(local_path: Path, logdir: Path):
  """Adds a logdir to the repository.
  :param local_path: repository directory
  :param logdir: logdir directory
  """
  if logdir.exists() and logdir.is_dir():
    # Add the logdir to the repository under new dir called logs
    repo_logdir = local_path / "logs"

    # Delete current logs if they exist
    if repo_logdir.exists():
      shutil.rmtree(repo_logdir)

    # Copy logdir into repo logdir
    shutil.copytree(logdir, repo_logdir)

def make_env(env_id, seed, idx, capture_video, run_name):
  def thunk():
    env = gym.make(env_id)
    env = gym.wrappers.RecordEpisodeStatistics(env)
    if capture_video:
      if idx == 0:
        env = gym.wrappers.RecordVideo(env, f"videos/{run_name}")
    env.seed(seed)
    env.action_space.seed(seed)
    env.observation_space.seed(seed)
    return env

  return thunk

def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
  torch.nn.init.orthogonal_(layer.weight, std)
  torch.nn.init.constant_(layer.bias, bias_const)
  return layer

class Agent(nn.Module):
  def __init__(self, envs):
    super().__init__()
    self.critic = nn.Sequential(
                  layer_init(nn.Linear(np.array(envs.single_observation_space.shape).prod(), 64)),
                  nn.Tanh(),
                  layer_init(nn.Linear(64, 64)),
                  nn.Tanh(),
                  layer_init(nn.Linear(64, 1), std=1.0),
                  )
    self.actor = nn.Sequential(
                  layer_init(nn.Linear(np.array(envs.single_observation_space.shape).prod(), 64)),
                  nn.Tanh(),
                  layer_init(nn.Linear(64, 64)),
                  nn.Tanh(),
                  layer_init(nn.Linear(64, envs.single_action_space.n), std=0.01),
                  )

  def get_value(self, x):
    return self.critic(x)

  def get_action_and_value(self, x, action=None):
    logits = self.actor(x)
    probs = Categorical(logits=logits)
    if action is None:
      action = probs.sample()
    return action, probs.log_prob(action), probs.entropy(), self.critic(x)

if __name__ == "__main__":
  args = parse_args()
  run_name = f"{args.env_id}__{args.exp_name}__{args.seed}__{int(time.time())}"
  if args.track:
    import wandb

    wandb.init(
        project=args.wandb_project_name,
        entity=args.wandb_entity,
        sync_tensorboard=True,
        config=vars(args),
        name=run_name,
        monitor_gym=True,
        save_code=True,
        )

  writer = SummaryWriter(f"runs/{run_name}")
  writer.add_text(
        "hyperparameters",
        "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
        )

  # TRY NOT TO MODIFY: seeding
  random.seed(args.seed)
  np.random.seed(args.seed)
  torch.manual_seed(args.seed)
  torch.backends.cudnn.deterministic = args.torch_deterministic

  device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")

  # env setup
  envs = gym.vector.SyncVectorEnv(
                  [make_env(args.env_id, args.seed + i, i, args.capture_video, run_name) for i in range(args.num_envs)]
                  )
  assert isinstance(envs.single_action_space, gym.spaces.Discrete), "only discrete action space is supported"

  agent = Agent(envs).to(device)
  optimizer = optim.Adam(agent.parameters(), lr=args.learning_rate, eps=1e-5)

  # ALGO Logic: Storage setup
  obs = torch.zeros((args.num_steps, args.num_envs) + envs.single_observation_space.shape).to(device)
  actions = torch.zeros((args.num_steps, args.num_envs) + envs.single_action_space.shape).to(device)
  logprobs = torch.zeros((args.num_steps, args.num_envs)).to(device)
  rewards = torch.zeros((args.num_steps, args.num_envs)).to(device)
  dones = torch.zeros((args.num_steps, args.num_envs)).to(device)
  values = torch.zeros((args.num_steps, args.num_envs)).to(device)

  # TRY NOT TO MODIFY: start the game
  global_step = 0
  start_time = time.time()
  next_obs = torch.Tensor(envs.reset()).to(device)
  next_done = torch.zeros(args.num_envs).to(device)
  num_updates = args.total_timesteps // args.batch_size

  for update in range(1, num_updates + 1):
    # Annealing the rate if instructed to do so.
    if args.anneal_lr:
      frac = 1.0 - (update - 1.0) / num_updates
      lrnow = frac * args.learning_rate
      optimizer.param_groups[0]["lr"] = lrnow

    for step in range(0, args.num_steps):
      global_step += 1 * args.num_envs
      obs[step] = next_obs
      dones[step] = next_done

      # ALGO LOGIC: action logic
      with torch.no_grad():
        action, logprob, _, value = agent.get_action_and_value(next_obs)
        values[step] = value.flatten()
      actions[step] = action
      logprobs[step] = logprob

      # TRY NOT TO MODIFY: execute the game and log data.
      next_obs, reward, done, info = envs.step(action.cpu().numpy())
      rewards[step] = torch.tensor(reward).to(device).view(-1)
      next_obs, next_done = torch.Tensor(next_obs).to(device), torch.Tensor(done).to(device)

      for item in info:
        if "episode" in item.keys():
          print(f"global_step={global_step}, episodic_return={item['episode']['r']}")
          writer.add_scalar("charts/episodic_return", item["episode"]["r"], global_step)
          writer.add_scalar("charts/episodic_length", item["episode"]["l"], global_step)
          break

    # bootstrap value if not done
    with torch.no_grad():
      next_value = agent.get_value(next_obs).reshape(1, -1)
      if args.gae:
        advantages = torch.zeros_like(rewards).to(device)
        lastgaelam = 0
        for t in reversed(range(args.num_steps)):
          if t == args.num_steps - 1:
            nextnonterminal = 1.0 - next_done
            nextvalues = next_value
          else:
            nextnonterminal = 1.0 - dones[t + 1]
            nextvalues = values[t + 1]
          delta = rewards[t] + args.gamma * nextvalues * nextnonterminal - values[t]
          advantages[t] = lastgaelam = delta + args.gamma * args.gae_lambda * nextnonterminal * lastgaelam
        returns = advantages + values
      else:
        returns = torch.zeros_like(rewards).to(device)
        for t in reversed(range(args.num_steps)):
          if t == args.num_steps - 1:
            nextnonterminal = 1.0 - next_done
            next_return = next_value
          else:
            nextnonterminal = 1.0 - dones[t + 1]
            next_return = returns[t + 1]
          returns[t] = rewards[t] + args.gamma * nextnonterminal * next_return
        advantages = returns - values

    # flatten the batch
    b_obs = obs.reshape((-1,) + envs.single_observation_space.shape)
    b_logprobs = logprobs.reshape(-1)
    b_actions = actions.reshape((-1,) + envs.single_action_space.shape)
    b_advantages = advantages.reshape(-1)
    b_returns = returns.reshape(-1)
    b_values = values.reshape(-1)

    # Optimizing the policy and value network
    b_inds = np.arange(args.batch_size)
    clipfracs = []
    for epoch in range(args.update_epochs):
      np.random.shuffle(b_inds)
      for start in range(0, args.batch_size, args.minibatch_size):
        end = start + args.minibatch_size
        mb_inds = b_inds[start:end]

        _, newlogprob, entropy, newvalue = agent.get_action_and_value(b_obs[mb_inds], b_actions.long()[mb_inds])
        logratio = newlogprob - b_logprobs[mb_inds]
        ratio = logratio.exp()

        with torch.no_grad():
          # calculate approx_kl http://joschu.net/blog/kl-approx.html
          old_approx_kl = (-logratio).mean()
          approx_kl = ((ratio - 1) - logratio).mean()
          clipfracs += [((ratio - 1.0).abs() > args.clip_coef).float().mean().item()]

        mb_advantages = b_advantages[mb_inds]
        if args.norm_adv:
          mb_advantages = (mb_advantages - mb_advantages.mean()) / (mb_advantages.std() + 1e-8)

        # Policy loss
        pg_loss1 = -mb_advantages * ratio
        pg_loss2 = -mb_advantages * torch.clamp(ratio, 1 - args.clip_coef, 1 + args.clip_coef)
        pg_loss = torch.max(pg_loss1, pg_loss2).mean()

        # Value loss
        newvalue = newvalue.view(-1)
        if args.clip_vloss:
          v_loss_unclipped = (newvalue - b_returns[mb_inds]) ** 2
          v_clipped = b_values[mb_inds] + torch.clamp(
              newvalue - b_values[mb_inds],
              -args.clip_coef,
              args.clip_coef,
          )
          v_loss_clipped = (v_clipped - b_returns[mb_inds]) ** 2
          v_loss_max = torch.max(v_loss_unclipped, v_loss_clipped)
          v_loss = 0.5 * v_loss_max.mean()
        else:
          v_loss = 0.5 * ((newvalue - b_returns[mb_inds]) ** 2).mean()

        entropy_loss = entropy.mean()
        loss = pg_loss - args.ent_coef * entropy_loss + v_loss * args.vf_coef

        optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(agent.parameters(), args.max_grad_norm)
        optimizer.step()

      if args.target_kl is not None:
        if approx_kl > args.target_kl:
          break

    y_pred, y_true = b_values.cpu().numpy(), b_returns.cpu().numpy()
    var_y = np.var(y_true)
    explained_var = np.nan if var_y == 0 else 1 - np.var(y_true - y_pred) / var_y

    # TRY NOT TO MODIFY: record rewards for plotting purposes
    writer.add_scalar("charts/learning_rate", optimizer.param_groups[0]["lr"], global_step)
    writer.add_scalar("losses/value_loss", v_loss.item(), global_step)
    writer.add_scalar("losses/policy_loss", pg_loss.item(), global_step)
    writer.add_scalar("losses/entropy", entropy_loss.item(), global_step)
    writer.add_scalar("losses/old_approx_kl", old_approx_kl.item(), global_step)
    writer.add_scalar("losses/approx_kl", approx_kl.item(), global_step)
    writer.add_scalar("losses/clipfrac", np.mean(clipfracs), global_step)
    writer.add_scalar("losses/explained_variance", explained_var, global_step)
    print("SPS:", int(global_step / (time.time() - start_time)))
    writer.add_scalar("charts/SPS", int(global_step / (time.time() - start_time)), global_step)

  envs.close()
  writer.close()

  # Create the evaluation environment
  eval_env = gym.make(args.env_id)

  package_to_hub(repo_id = args.repo_id,
        model = agent, # The model we want to save
        hyperparameters = args,
        eval_env = gym.make(args.env_id),
        logs= f"runs/{run_name}",
        )

# %%
# !python ppo.py --env-id="LunarLander-v2" --repo-id="Weiming1122/ppo-LunarLander-v2-unit8" --total-timesteps=10000000
# Out:
# Streaming output truncated to the last 5000 lines.
# global_step=6138480, episodic_return=-52.70071792602539
# global_step=6138528, episodic_return=205.91355895996094
# global_step=6139104, episodic_return=108.7463150024414
# global_step=6139344, episodic_return=183.7469024658203
# global_step=6139712, episodic_return=214.35775756835938
# global_step=6140208, episodic_return=107.61511993408203
# global_step=6141104, episodic_return=134.53524780273438
# global_step=6141728, episodic_return=102.25550079345703
# global_step=6142640, episodic_return=245.7770538330078
# global_step=6142816, episodic_return=147.87364196777344
# global_step=6143520, episodic_return=229.64678955078125
# global_step=6144032, episodic_return=147.43743896484375
# global_step=6144368, episodic_return=191.88226318359375
# global_step=6144384, episodic_return=138.56021118164062
# global_step=6144448, episodic_return=157.6951141357422
# global_step=6147280, episodic_return=99.98551177978516
# global_step=6147376, episodic_return=232.97169494628906
# global_step=6147536, episodic_return=199.66116333007812
# global_step=6147968, episodic_return=221.48817443847656
# global_step=6149808, episodic_return=99.9080581665039
# global_step=6154480, episodic_return=121.42646026611328
# global_step=6155344, episodic_return=132.71823120117188
# global_step=6155712, episodic_return=140.0187530517578
# global_step=6156208, episodic_return=114.03006744384766
# global_step=6157104, episodic_return=95.3482437133789
# global_step=6158640, episodic_return=121.28047943115234
# global_step=6159520, episodic_return=121.83547973632812
# global_step=6160032, episodic_return=142.13743591308594
# global_step=6160368, episodic_return=70.35187530517578
# global_step=6160384, episodic_return=140.35519409179688
# SPS: 884
# global_step=6160448, episodic_return=113.36632537841797
# global_step=6163280, episodic_return=143.52481079101562
# global_step=6163376, episodic_return=122.50476837158203
# global_step=6163536, episodic_return=137.9481201171875
# global_step=6163968, episodic_return=109.57131958007812
# global_step=6164496, episodic_return=219.54751586914062
# global_step=6165808, episodic_return=135.67010498046875
# global_step=6166448, episodic_return=173.6939697265625
# global_step=6166640, episodic_return=220.3916015625
# global_step=6170480, episodic_return=123.4521255493164
# global_step=6171344, episodic_return=115.44928741455078
# global_step=6171664, episodic_return=207.85092163085938
# global_step=6172208, episodic_return=104.34138488769531
# global_step=6174640, episodic_return=120.19161224365234
# global_step=6175520, episodic_return=148.69305419921875
# global_step=6176032, episodic_return=95.01583099365234
# global_step=6176384, episodic_return=98.80831909179688
# global_step=6176608, episodic_return=223.00650024414062
# global_step=6178016, episodic_return=190.72113037109375
# global_step=6179280, episodic_return=95.2625961303711
# global_step=6179376, episodic_return=129.21987915039062
# global_step=6179536, episodic_return=169.9422149658203
# global_step=6179968, episodic_return=141.2709503173828
# global_step=6180496, episodic_return=145.2646484375
# global_step=6181296, episodic_return=233.7401885986328
# global_step=6181808, episodic_return=140.46604919433594
# global_step=6181856, episodic_return=224.54910278320312
# global_step=6182448, episodic_return=95.35680389404297
# global_step=6183456, episodic_return=228.80360412597656
# global_step=6185552, episodic_return=2.949615478515625
# global_step=6186544, episodic_return=209.53372192382812
# global_step=6187344, episodic_return=132.046630859375
# global_step=6187664, episodic_return=130.4315643310547
# global_step=6188208, episodic_return=95.64067840576172
# global_step=6191520, episodic_return=142.73558044433594
# global_step=6192144, episodic_return=183.8316192626953
# global_step=6192384, episodic_return=121.44554138183594
# global_step=6192608, episodic_return=139.4849395751953
# global_step=6192736, episodic_return=211.32638549804688
# SPS: 883
# global_step=6193392, episodic_return=239.1874237060547
# global_step=6195536, episodic_return=129.77005004882812
# global_step=6195968, episodic_return=158.0801239013672
# global_step=6197296, episodic_return=150.24021911621094
# global_step=6197808, episodic_return=119.28229522705078
# global_step=6197856, episodic_return=115.90144348144531
# global_step=6198448, episodic_return=130.47525024414062
# global_step=6199456, episodic_return=153.10643005371094
# global_step=6202992, episodic_return=192.25677490234375
# global_step=6203104, episodic_return=-12.308296203613281
# global_step=6203344, episodic_return=158.52618408203125
# global_step=6203664, episodic_return=143.9089813232422
# global_step=6204208, episodic_return=60.48580551147461
# global_step=6207520, episodic_return=92.13035583496094
# global_step=6208144, episodic_return=114.6926040649414
# global_step=6208384, episodic_return=114.5861587524414
# global_step=6208608, episodic_return=126.25955200195312
# global_step=6208736, episodic_return=101.53764343261719
# global_step=6210208, episodic_return=216.52032470703125
# global_step=6211536, episodic_return=145.604248046875
# global_step=6211968, episodic_return=136.99269104003906
# global_step=6213296, episodic_return=84.85457611083984
# global_step=6213392, episodic_return=-61.90540313720703
# global_step=6213856, episodic_return=85.41019439697266
# global_step=6214448, episodic_return=137.26559448242188
# global_step=6215456, episodic_return=90.90436553955078
# global_step=6218992, episodic_return=110.90868377685547
# global_step=6219184, episodic_return=202.0865478515625
# global_step=6219344, episodic_return=95.3821029663086
# global_step=6219664, episodic_return=147.6446990966797
# global_step=6220112, episodic_return=185.03115844726562
# global_step=6220208, episodic_return=124.41167449951172
# global_step=6220416, episodic_return=211.6510772705078
# global_step=6222816, episodic_return=198.69094848632812
# global_step=6223520, episodic_return=137.95045471191406
# global_step=6224608, episodic_return=63.02924728393555
# global_step=6224736, episodic_return=104.05119323730469
# SPS: 882
# global_step=6226208, episodic_return=123.33586883544922
# global_step=6229392, episodic_return=106.63497161865234
# global_step=6229856, episodic_return=149.0582733154297
# global_step=6230448, episodic_return=154.23788452148438
# global_step=6231456, episodic_return=139.30929565429688
# global_step=6231520, episodic_return=179.32720947265625
# global_step=6231952, episodic_return=199.22189331054688
# global_step=6233184, episodic_return=-22.70306396484375
# global_step=6234992, episodic_return=106.57689666748047
# global_step=6235184, episodic_return=84.74781036376953
# global_step=6235344, episodic_return=97.61915588378906
# global_step=6235664, episodic_return=132.94053649902344
# global_step=6236112, episodic_return=102.1645278930664
# global_step=6236208, episodic_return=139.1451416015625
# global_step=6236416, episodic_return=156.16969299316406
# global_step=6237952, episodic_return=28.246368408203125
# global_step=6238272, episodic_return=163.4049530029297
# global_step=6238816, episodic_return=116.6806640625
# global_step=6239520, episodic_return=140.78033447265625
# global_step=6242208, episodic_return=159.78305053710938
# global_step=6245856, episodic_return=151.7169647216797
# global_step=6246448, episodic_return=93.5221939086914
# global_step=6247456, episodic_return=147.4103546142578
# global_step=6247520, episodic_return=131.64920043945312
# global_step=6250992, episodic_return=106.2535171508789
# global_step=6251184, episodic_return=120.343017578125
# global_step=6251344, episodic_return=140.131103515625
# global_step=6251664, episodic_return=142.80043029785156
# global_step=6252112, episodic_return=144.97378540039062
# global_step=6252208, episodic_return=87.37625885009766
# global_step=6252416, episodic_return=99.16898345947266
# global_step=6253952, episodic_return=124.50617980957031
# global_step=6254272, episodic_return=102.76944732666016
# global_step=6254816, episodic_return=108.73450469970703
# global_step=6255520, episodic_return=110.9813461303711
# global_step=6256208, episodic_return=-2.3808746337890625
# global_step=6258208, episodic_return=152.09925842285156
# SPS: 881
# global_step=6259952, episodic_return=-6.2357635498046875
# global_step=6261856, episodic_return=100.32689666748047
# global_step=6262288, episodic_return=182.2825927734375
# global_step=6262448, episodic_return=141.23333740234375
# global_step=6263456, episodic_return=120.6597671508789
# global_step=6263520, episodic_return=137.59994506835938
# global_step=6265408, episodic_return=0.804168701171875
# global_step=6267184, episodic_return=123.0306396484375
# global_step=6267248, episodic_return=-10.918190002441406
# global_step=6267344, episodic_return=128.1909637451172
# global_step=6267664, episodic_return=91.48841094970703
# global_step=6267952, episodic_return=-57.81422424316406
# global_step=6268112, episodic_return=149.1000518798828
# global_step=6268208, episodic_return=134.85264587402344
# global_step=6269952, episodic_return=120.2906723022461
# global_step=6270272, episodic_return=89.18827819824219
# global_step=6270816, episodic_return=126.44761657714844
# global_step=6271728, episodic_return=-33.571502685546875
# global_step=6272208, episodic_return=67.10040283203125
# global_step=6272928, episodic_return=224.9542236328125
# global_step=6274208, episodic_return=106.4085693359375
# global_step=6277856, episodic_return=135.8443603515625
# global_step=6278448, episodic_return=125.52091979980469
# global_step=6279520, episodic_return=108.42744445800781
# global_step=6283184, episodic_return=126.13948822021484
# global_step=6283248, episodic_return=126.70714569091797
# global_step=6283344, episodic_return=155.4690399169922
# global_step=6283872, episodic_return=-5.384765625
# global_step=6283952, episodic_return=137.27105712890625
# global_step=6284112, episodic_return=145.9875946044922
# global_step=6284208, episodic_return=101.54476165771484
# global_step=6285952, episodic_return=146.82269287109375
# global_step=6286272, episodic_return=143.8369140625
# global_step=6286816, episodic_return=120.59501647949219
# global_step=6287728, episodic_return=127.4892349243164
# global_step=6288208, episodic_return=136.6569061279297
# global_step=6288928, episodic_return=69.2298355102539
# global_step=6290208, episodic_return=94.55781555175781
# global_step=6291392, episodic_return=29.510116577148438
# SPS: 879
# global_step=6292560, episodic_return=182.81106567382812
# global_step=6293856, episodic_return=115.55817413330078
# global_step=6294448, episodic_return=100.26909637451172
# global_step=6298464, episodic_return=186.64535522460938
# global_step=6299184, episodic_return=114.21578979492188
# global_step=6299248, episodic_return=144.46119689941406
# global_step=6299344, episodic_return=161.3625030517578
# global_step=6299392, episodic_return=217.76693725585938
# global_step=6299872, episodic_return=110.96138000488281
# global_step=6299952, episodic_return=104.19287872314453
# global_step=6300112, episodic_return=136.2118682861328
# global_step=6300208, episodic_return=145.52359008789062
# global_step=6301952, episodic_return=135.0458526611328
# global_step=6302464, episodic_return=190.13230895996094
# global_step=6303024, episodic_return=24.98565673828125
# global_step=6303728, episodic_return=102.16925811767578
# global_step=6304208, episodic_return=100.8025894165039
# global_step=6305456, episodic_return=35.33882141113281
# global_step=6306208, episodic_return=128.43951416015625
# global_step=6306384, episodic_return=-13.185745239257812
# global_step=6307152, episodic_return=205.26600646972656
# global_step=6307312, episodic_return=212.23809814453125
# global_step=6307392, episodic_return=147.6390838623047
# global_step=6309856, episodic_return=169.7336883544922
# global_step=6311616, episodic_return=-12.581802368164062
# global_step=6312544, episodic_return=215.86163330078125
# global_step=6315184, episodic_return=137.7463836669922
# global_step=6315344, episodic_return=110.03030395507812
# global_step=6315392, episodic_return=114.4934310913086
# global_step=6315872, episodic_return=116.04883575439453
# global_step=6315952, episodic_return=139.5059814453125
# global_step=6318464, episodic_return=99.81373596191406
# global_step=6319024, episodic_return=134.26275634765625
# global_step=6319728, episodic_return=126.04026794433594
# global_step=6320208, episodic_return=139.97775268554688
# global_step=6322208, episodic_return=102.36470031738281
# global_step=6323152, episodic_return=115.05291748046875
# global_step=6323312, episodic_return=105.23766326904297
# global_step=6323392, episodic_return=146.3677520751953
# SPS: 878
# global_step=6325856, episodic_return=109.3284683227539
# global_step=6327616, episodic_return=174.24363708496094
# global_step=6328544, episodic_return=159.9114532470703
# global_step=6329968, episodic_return=191.76339721679688
# global_step=6331184, episodic_return=112.9813461303711
# global_step=6331344, episodic_return=123.61978149414062
# global_step=6331392, episodic_return=80.60486602783203
# global_step=6331840, episodic_return=-3.468170166015625
# global_step=6331872, episodic_return=107.7559585571289
# global_step=6331952, episodic_return=137.25303649902344
# global_step=6334464, episodic_return=141.0187530517578
# global_step=6335024, episodic_return=149.56417846679688
# global_step=6335728, episodic_return=97.40587615966797
# global_step=6336208, episodic_return=117.03658294677734
# global_step=6336256, episodic_return=-43.43881607055664
# global_step=6336608, episodic_return=8.248565673828125
# global_step=6338208, episodic_return=94.22882843017578
# global_step=6338720, episodic_return=185.92919921875
# global_step=6339152, episodic_return=160.51284790039062
# global_step=6339392, episodic_return=115.08773040771484
# global_step=6341856, episodic_return=113.27946472167969
# global_step=6344544, episodic_return=131.64321899414062
# global_step=6344896, episodic_return=242.0523223876953
# global_step=6345968, episodic_return=133.5570068359375
# global_step=6346224, episodic_return=196.6664276123047
# global_step=6346256, episodic_return=172.19598388671875
# global_step=6347184, episodic_return=150.0453338623047
# global_step=6347344, episodic_return=106.55563354492188
# global_step=6347952, episodic_return=111.69131469726562
# global_step=6350464, episodic_return=125.73946380615234
# global_step=6351024, episodic_return=117.5400390625
# global_step=6351600, episodic_return=170.0826873779297
# global_step=6351728, episodic_return=123.03612518310547
# global_step=6352208, episodic_return=106.99569702148438
# global_step=6352608, episodic_return=112.95475769042969
# global_step=6354208, episodic_return=143.75343322753906
# global_step=6355152, episodic_return=123.22689819335938
# global_step=6355936, episodic_return=169.78118896484375
# global_step=6356080, episodic_return=246.2455291748047
# SPS: 877
# global_step=6360544, episodic_return=112.95294952392578
# global_step=6361968, episodic_return=130.70852661132812
# global_step=6362224, episodic_return=166.00917053222656
# global_step=6362256, episodic_return=141.39463806152344
# global_step=6363184, episodic_return=109.42223358154297
# global_step=6363344, episodic_return=122.08746337890625
# global_step=6363952, episodic_return=138.27903747558594
# global_step=6364048, episodic_return=207.77159118652344
# global_step=6367024, episodic_return=170.84654235839844
# global_step=6367600, episodic_return=139.7269287109375
# global_step=6367728, episodic_return=126.2416000366211
# global_step=6368208, episodic_return=152.3586883544922
# global_step=6368608, episodic_return=133.72109985351562
# global_step=6370208, episodic_return=94.5539779663086
# global_step=6370384, episodic_return=176.47801208496094
# global_step=6370544, episodic_return=210.39590454101562
# global_step=6371936, episodic_return=93.92903137207031
# global_step=6372080, episodic_return=152.98216247558594
# global_step=6372752, episodic_return=186.6007537841797
# global_step=6374368, episodic_return=209.7482452392578
# global_step=6376544, episodic_return=120.04084777832031
# global_step=6377264, episodic_return=-67.46527099609375
# global_step=6377968, episodic_return=125.0174331665039
# global_step=6378224, episodic_return=115.75830078125
# global_step=6378256, episodic_return=119.5953598022461
# global_step=6380048, episodic_return=77.74309539794922
# global_step=6381344, episodic_return=-5.799919128417969
# global_step=6381616, episodic_return=194.35311889648438
# global_step=6383120, episodic_return=232.7906494140625
# global_step=6383600, episodic_return=155.38934326171875
# global_step=6383728, episodic_return=108.98988342285156
# global_step=6384208, episodic_return=116.67530059814453
# global_step=6384608, episodic_return=138.60784912109375
# global_step=6385296, episodic_return=214.37716674804688
# global_step=6386208, episodic_return=140.74911499023438
# global_step=6386544, episodic_return=117.3258056640625
# global_step=6387936, episodic_return=76.77442169189453
# global_step=6388080, episodic_return=116.78604888916016
# SPS: 876
# global_step=6390336, episodic_return=199.07489013671875
# global_step=6390368, episodic_return=102.12368774414062
# global_step=6391520, episodic_return=213.70375061035156
# global_step=6393264, episodic_return=121.50567626953125
# global_step=6393968, episodic_return=135.81739807128906
# global_step=6394992, episodic_return=-29.983306884765625
# global_step=6396048, episodic_return=93.60206604003906
# global_step=6397344, episodic_return=74.4874038696289
# global_step=6397616, episodic_return=137.92906188964844
# global_step=6398688, episodic_return=238.9770050048828
# global_step=6399120, episodic_return=111.0005874633789
# global_step=6399600, episodic_return=126.22479248046875
# global_step=6399728, episodic_return=147.79136657714844
# global_step=6400208, episodic_return=102.51582336425781
# global_step=6401296, episodic_return=198.6389923095703
# global_step=6402544, episodic_return=99.88045501708984
# global_step=6403936, episodic_return=136.01617431640625
# global_step=6404080, episodic_return=118.57550048828125
# global_step=6405088, episodic_return=170.88230895996094
# global_step=6406368, episodic_return=107.55936431884766
# global_step=6406480, episodic_return=229.25067138671875
# global_step=6407520, episodic_return=115.14326477050781
# global_step=6408112, episodic_return=189.91651916503906
# global_step=6409968, episodic_return=153.71002197265625
# global_step=6410112, episodic_return=188.09129333496094
# global_step=6412048, episodic_return=94.5329360961914
# global_step=6413344, episodic_return=127.29353332519531
# global_step=6414688, episodic_return=114.4536361694336
# global_step=6415600, episodic_return=116.18026733398438
# global_step=6415728, episodic_return=71.86249542236328
# global_step=6416208, episodic_return=144.1016845703125
# global_step=6416368, episodic_return=173.2776336669922
# global_step=6417296, episodic_return=119.78018951416016
# global_step=6418544, episodic_return=118.01280212402344
# global_step=6419936, episodic_return=124.48190307617188
# global_step=6421088, episodic_return=143.57476806640625
# global_step=6422368, episodic_return=128.410888671875
# global_step=6422480, episodic_return=100.68438720703125
# SPS: 875
# global_step=6423520, episodic_return=135.35482788085938
# global_step=6424112, episodic_return=123.02890014648438
# global_step=6426112, episodic_return=116.617919921875
# global_step=6427488, episodic_return=229.08663940429688
# global_step=6428048, episodic_return=131.18881225585938
# global_step=6428896, episodic_return=192.37045288085938
# global_step=6429344, episodic_return=142.1800537109375
# global_step=6430688, episodic_return=150.3507080078125
# global_step=6431536, episodic_return=-59.45735549926758
# global_step=6431600, episodic_return=121.85671997070312
# global_step=6431728, episodic_return=99.77845764160156
# global_step=6432208, episodic_return=133.1223602294922
# global_step=6432368, episodic_return=111.88739013671875
# global_step=6432800, episodic_return=185.90943908691406
# global_step=6433136, episodic_return=-20.558990478515625
# global_step=6433296, episodic_return=134.79559326171875
# global_step=6434544, episodic_return=113.38176727294922
# global_step=6437088, episodic_return=144.26014709472656
# global_step=6438480, episodic_return=91.33415985107422
# global_step=6439520, episodic_return=152.32049560546875
# global_step=6440112, episodic_return=101.04390716552734
# global_step=6441248, episodic_return=176.7113494873047
# global_step=6444048, episodic_return=107.57715606689453
# global_step=6445344, episodic_return=121.12320709228516
# global_step=6445568, episodic_return=237.39108276367188
# global_step=6446688, episodic_return=146.35031127929688
# global_step=6447536, episodic_return=103.10155487060547
# global_step=6447600, episodic_return=158.59649658203125
# global_step=6447728, episodic_return=28.070528030395508
# global_step=6448208, episodic_return=125.96394348144531
# global_step=6448368, episodic_return=102.14593505859375
# global_step=6448800, episodic_return=112.3680419921875
# global_step=6449136, episodic_return=127.12409210205078
# global_step=6450544, episodic_return=81.13363647460938
# global_step=6451680, episodic_return=202.7726593017578
# global_step=6453088, episodic_return=124.05101776123047
# global_step=6454480, episodic_return=117.07527160644531
# SPS: 874
# global_step=6456112, episodic_return=126.552734375
# global_step=6456912, episodic_return=170.41598510742188
# global_step=6457248, episodic_return=164.22259521484375
# global_step=6459488, episodic_return=27.788047790527344
# global_step=6461024, episodic_return=212.95394897460938
# global_step=6461344, episodic_return=100.13221740722656
# global_step=6462688, episodic_return=144.7331085205078
# global_step=6463536, episodic_return=148.2691192626953
# global_step=6463600, episodic_return=132.19374084472656
# global_step=6463728, episodic_return=139.463623046875
# global_step=6463744, episodic_return=209.48239135742188
# global_step=6464208, episodic_return=99.05591583251953
# global_step=6464224, episodic_return=173.43405151367188
# global_step=6464368, episodic_return=152.33184814453125
# global_step=6464800, episodic_return=103.38691711425781
# global_step=6465136, episodic_return=109.88836669921875
# global_step=6469088, episodic_return=159.49436950683594
# global_step=6469968, episodic_return=188.0027618408203
# global_step=6470448, episodic_return=228.06141662597656
# global_step=6471184, episodic_return=206.4235076904297
# global_step=6472112, episodic_return=130.88494873046875
# global_step=6473248, episodic_return=121.30274963378906
# global_step=6474000, episodic_return=7.147186279296875
# global_step=6475488, episodic_return=136.3423614501953
# global_step=6477024, episodic_return=120.52099609375
# global_step=6477344, episodic_return=117.10445404052734
# global_step=6477488, episodic_return=168.29400634765625
# global_step=6477808, episodic_return=194.42431640625
# global_step=6478688, episodic_return=74.30038452148438
# global_step=6479536, episodic_return=184.03005981445312
# global_step=6479600, episodic_return=124.15612030029297
# global_step=6480208, episodic_return=135.25953674316406
# global_step=6480224, episodic_return=118.63935852050781
# global_step=6480368, episodic_return=107.9107894897461
# global_step=6480800, episodic_return=125.8260269165039
# global_step=6481136, episodic_return=98.22208404541016
# global_step=6486320, episodic_return=198.84478759765625
# global_step=6486448, episodic_return=133.39491271972656
# global_step=6487184, episodic_return=122.2784652709961
# SPS: 873
# global_step=6488544, episodic_return=227.216796875
# global_step=6490000, episodic_return=111.94596099853516
# global_step=6491488, episodic_return=105.42124938964844
# global_step=6493024, episodic_return=84.47093963623047
# global_step=6493152, episodic_return=199.5990753173828
# global_step=6493344, episodic_return=105.29296112060547
# global_step=6493488, episodic_return=125.05493927001953
# global_step=6493808, episodic_return=124.50276184082031
# global_step=6494688, episodic_return=107.29851531982422
# global_step=6495600, episodic_return=153.4661102294922
# global_step=6496224, episodic_return=173.4216766357422
# global_step=6496368, episodic_return=127.16732788085938
# global_step=6496800, episodic_return=167.86984252929688
# global_step=6497136, episodic_return=136.30673217773438
# global_step=6502224, episodic_return=190.1796875
# global_step=6502448, episodic_return=157.9307098388672
# global_step=6503184, episodic_return=103.31388092041016
# global_step=6504544, episodic_return=80.0971908569336
# global_step=6506000, episodic_return=129.19398498535156
# global_step=6507488, episodic_return=154.5693359375
# global_step=6509024, episodic_return=82.50824737548828
# global_step=6509152, episodic_return=136.77786254882812
# global_step=6509344, episodic_return=100.96311950683594
# global_step=6509488, episodic_return=132.16062927246094
# global_step=6509808, episodic_return=120.13092041015625
# global_step=6510688, episodic_return=139.3652801513672
# global_step=6512224, episodic_return=117.7350845336914
# global_step=6512368, episodic_return=139.31192016601562
# global_step=6512800, episodic_return=114.94805145263672
# global_step=6513136, episodic_return=108.49403381347656
# global_step=6517136, episodic_return=1.35064697265625
# global_step=6518224, episodic_return=125.98095703125
# global_step=6518448, episodic_return=120.78192138671875
# global_step=6519184, episodic_return=128.0869903564453
# global_step=6519664, episodic_return=186.75088500976562
# global_step=6520544, episodic_return=130.5524444580078
# SPS: 873
# global_step=6522000, episodic_return=91.6491928100586
# global_step=6522096, episodic_return=-11.308860778808594
# global_step=6523168, episodic_return=181.35470581054688
# global_step=6523488, episodic_return=120.72705841064453
# global_step=6524848, episodic_return=220.88522338867188
# global_step=6525024, episodic_return=129.82583618164062
# global_step=6525152, episodic_return=94.76791381835938
# global_step=6525344, episodic_return=115.7608413696289
# global_step=6525488, episodic_return=63.769779205322266
# global_step=6525808, episodic_return=120.89986419677734
# global_step=6526688, episodic_return=126.86998748779297
# global_step=6527824, episodic_return=213.61007690429688
# global_step=6528800, episodic_return=157.42776489257812
# global_step=6529136, episodic_return=81.3759765625
# global_step=6530128, episodic_return=22.663490295410156
# global_step=6531888, episodic_return=229.43287658691406
# global_step=6531920, episodic_return=159.447998046875
# global_step=6532864, episodic_return=210.067626953125
# global_step=6533664, episodic_return=179.89022827148438
# global_step=6534448, episodic_return=100.13861083984375
# global_step=6535664, episodic_return=119.4013671875
# global_step=6536096, episodic_return=-45.2705078125
# global_step=6537776, episodic_return=-12.694442749023438
# global_step=6537888, episodic_return=243.33969116210938
# global_step=6538000, episodic_return=90.1876449584961
# global_step=6539488, episodic_return=106.18391418457031
# global_step=6540848, episodic_return=134.2510223388672
# global_step=6540928, episodic_return=188.397705078125
# global_step=6541344, episodic_return=153.23109436035156
# global_step=6541488, episodic_return=119.23181915283203
# global_step=6541808, episodic_return=159.74110412597656
# global_step=6542480, episodic_return=177.7997283935547
# global_step=6543008, episodic_return=131.4810791015625
# global_step=6543840, episodic_return=193.1043243408203
# global_step=6544800, episodic_return=153.44876098632812
# global_step=6545136, episodic_return=134.96385192871094
# global_step=6545600, episodic_return=-21.169204711914062
# global_step=6547152, episodic_return=-40.810367584228516
# global_step=6547536, episodic_return=180.95071411132812
# global_step=6547920, episodic_return=112.3609390258789
# global_step=6548528, episodic_return=200.10360717773438
# global_step=6548864, episodic_return=102.70986938476562
# global_step=6551344, episodic_return=197.5747528076172
# global_step=6551664, episodic_return=85.90088653564453
# global_step=6552896, episodic_return=174.74853515625
# SPS: 872
# global_step=6554000, episodic_return=107.56232452392578
# global_step=6555488, episodic_return=76.62640380859375
# global_step=6555584, episodic_return=182.61676025390625
# global_step=6556000, episodic_return=172.46649169921875
# global_step=6556928, episodic_return=81.98678588867188
# global_step=6557488, episodic_return=113.5147705078125
# global_step=6557648, episodic_return=202.9442138671875
# global_step=6557808, episodic_return=132.24085998535156
# global_step=6559840, episodic_return=102.62355041503906
# global_step=6560672, episodic_return=31.452789306640625
# global_step=6561152, episodic_return=178.38125610351562
# global_step=6561600, episodic_return=135.77084350585938
# global_step=6563536, episodic_return=119.62324523925781
# global_step=6563920, episodic_return=134.74969482421875
# global_step=6564528, episodic_return=116.18821716308594
# global_step=6565968, episodic_return=-25.98668670654297
# global_step=6567344, episodic_return=147.90357971191406
# global_step=6568896, episodic_return=88.7208480834961
# global_step=6569776, episodic_return=6.525535583496094
# global_step=6570000, episodic_return=116.96469116210938
# global_step=6571488, episodic_return=109.54252624511719
# global_step=6571584, episodic_return=116.77074432373047
# global_step=6572928, episodic_return=141.833251953125
# global_step=6573488, episodic_return=100.61390686035156
# global_step=6573648, episodic_return=144.60069274902344
# global_step=6573808, episodic_return=137.90081787109375
# global_step=6574464, episodic_return=229.8773956298828
# global_step=6575840, episodic_return=129.1300506591797
# global_step=6576384, episodic_return=192.99185180664062
# global_step=6576672, episodic_return=142.57908630371094
# global_step=6577136, episodic_return=241.50491333007812
# global_step=6578560, episodic_return=200.552734375
# global_step=6579536, episodic_return=114.16214752197266
# global_step=6579632, episodic_return=240.00634765625
# global_step=6579920, episodic_return=128.77325439453125
# global_step=6581760, episodic_return=8.741691589355469
# global_step=6581968, episodic_return=166.47499084472656
# global_step=6582048, episodic_return=200.32601928710938
# global_step=6583344, episodic_return=152.42848205566406
# global_step=6584544, episodic_return=-38.55432891845703
# SPS: 872
# global_step=6586464, episodic_return=42.96522521972656
# global_step=6587488, episodic_return=102.90531158447266
# global_step=6587584, episodic_return=154.70944213867188
# global_step=6588528, episodic_return=207.62908935546875
# global_step=6588688, episodic_return=167.6998291015625
# global_step=6588928, episodic_return=136.4198455810547
# global_step=6589488, episodic_return=117.14065551757812
# global_step=6589648, episodic_return=145.38580322265625
# global_step=6591840, episodic_return=129.81785583496094
# global_step=6592384, episodic_return=162.93429565429688
# global_step=6592672, episodic_return=101.90129089355469
# global_step=6593472, episodic_return=184.7943878173828
# global_step=6594208, episodic_return=-20.90863037109375
# global_step=6594800, episodic_return=-10.139778137207031
# global_step=6595536, episodic_return=110.94957733154297
# global_step=6595632, episodic_return=213.7896270751953
# global_step=6596128, episodic_return=170.65200805664062
# global_step=6597968, episodic_return=149.002685546875
# global_step=6598048, episodic_return=108.12316131591797
# global_step=6600288, episodic_return=190.94146728515625
# global_step=6600544, episodic_return=142.51515197753906
# global_step=6600560, episodic_return=217.530517578125
# global_step=6602464, episodic_return=139.00125122070312
# global_step=6603392, episodic_return=153.35594177246094
# global_step=6603488, episodic_return=147.81361389160156
# global_step=6603696, episodic_return=204.94430541992188
# global_step=6604688, episodic_return=128.40235900878906
# global_step=6605040, episodic_return=-17.738082885742188
# global_step=6607840, episodic_return=128.10694885253906
# global_step=6608080, episodic_return=-18.51793670654297
# global_step=6608384, episodic_return=87.81045532226562
# global_step=6608928, episodic_return=240.31588745117188
# global_step=6610208, episodic_return=139.3353729248047
# global_step=6610800, episodic_return=144.64674377441406
# global_step=6611536, episodic_return=124.58277893066406
# global_step=6611632, episodic_return=140.81056213378906
# global_step=6612128, episodic_return=103.9662094116211
# global_step=6612320, episodic_return=-33.54304504394531
# global_step=6614048, episodic_return=134.9474334716797
# global_step=6615040, episodic_return=190.25515747070312
# global_step=6616288, episodic_return=113.37135314941406
# global_step=6616544, episodic_return=114.86451721191406
# global_step=6618544, episodic_return=187.29721069335938
# SPS: 872
# global_step=6619488, episodic_return=150.9043731689453
# global_step=6619696, episodic_return=104.30892944335938
# global_step=6620272, episodic_return=-30.312530517578125
# global_step=6620688, episodic_return=144.7965850830078
# global_step=6621040, episodic_return=126.27828216552734
# global_step=6622096, episodic_return=131.10888671875
# global_step=6623344, episodic_return=-14.559158325195312
# global_step=6624384, episodic_return=140.44314575195312
# global_step=6624928, episodic_return=114.42212677001953
# global_step=6626208, episodic_return=107.29142761230469
# global_step=6626800, episodic_return=124.14947509765625
# global_step=6626896, episodic_return=209.69244384765625
# global_step=6628128, episodic_return=106.55087280273438
# global_step=6628320, episodic_return=133.31829833984375
# global_step=6630048, episodic_return=147.3839569091797
# global_step=6631040, episodic_return=123.18733978271484
# global_step=6632464, episodic_return=13.482330322265625
# global_step=6632544, episodic_return=149.6798095703125
# global_step=6635488, episodic_return=139.3465576171875
# global_step=6635696, episodic_return=99.68221282958984
# global_step=6636272, episodic_return=107.34878540039062
# global_step=6636640, episodic_return=220.78125
# global_step=6636688, episodic_return=113.2176284790039
# global_step=6637984, episodic_return=251.315673828125
# global_step=6638096, episodic_return=131.5528564453125
# global_step=6639344, episodic_return=106.20684814453125
# global_step=6639440, episodic_return=-33.91276550292969
# global_step=6640384, episodic_return=107.15812683105469
# global_step=6640928, episodic_return=139.76513671875
# global_step=6641536, episodic_return=-1.153106689453125
# global_step=6642208, episodic_return=117.3366470336914
# global_step=6642400, episodic_return=220.8701171875
# global_step=6642800, episodic_return=132.81016540527344
# global_step=6642896, episodic_return=132.3308563232422
# global_step=6644320, episodic_return=159.39576721191406
# global_step=6646192, episodic_return=-11.844718933105469
# global_step=6646560, episodic_return=203.5648193359375
# global_step=6647040, episodic_return=145.168701171875
# global_step=6648544, episodic_return=142.64828491210938
# global_step=6649200, episodic_return=176.92684936523438
# global_step=6651488, episodic_return=137.2329864501953
# SPS: 871
# global_step=6652272, episodic_return=141.79962158203125
# global_step=6654080, episodic_return=222.27536010742188
# global_step=6654576, episodic_return=218.678466796875
# global_step=6655344, episodic_return=138.58070373535156
# global_step=6655440, episodic_return=122.12857055664062
# global_step=6656384, episodic_return=128.1443634033203
# global_step=6656928, episodic_return=130.74151611328125
# global_step=6658208, episodic_return=133.35244750976562
# global_step=6658400, episodic_return=130.04759216308594
# global_step=6658800, episodic_return=114.82601165771484
# global_step=6660320, episodic_return=106.803955078125
# global_step=6662192, episodic_return=77.94992065429688
# global_step=6662560, episodic_return=125.58049774169922
# global_step=6664544, episodic_return=107.39908599853516
# global_step=6665200, episodic_return=136.62619018554688
# global_step=6667488, episodic_return=135.25747680664062
# global_step=6668272, episodic_return=98.96561431884766
# global_step=6670080, episodic_return=99.84027099609375
# global_step=6670576, episodic_return=151.2516632080078
# global_step=6671344, episodic_return=146.66720581054688
# global_step=6671440, episodic_return=76.18589782714844
# global_step=6672384, episodic_return=132.68869018554688
# global_step=6672928, episodic_return=75.36022186279297
# global_step=6674208, episodic_return=135.2462615966797
# global_step=6674400, episodic_return=171.157958984375
# global_step=6674800, episodic_return=88.57389831542969
# global_step=6675904, episodic_return=-28.40528106689453
# global_step=6676320, episodic_return=138.42410278320312
# global_step=6676816, episodic_return=34.91905212402344
# global_step=6677360, episodic_return=226.7918701171875
# global_step=6678192, episodic_return=146.18797302246094
# global_step=6678560, episodic_return=62.4473876953125
# global_step=6680512, episodic_return=180.07205200195312
# global_step=6680544, episodic_return=134.42832946777344
# global_step=6681200, episodic_return=131.86328125
# global_step=6682000, episodic_return=214.46852111816406
# global_step=6682496, episodic_return=152.07925415039062
# global_step=6683200, episodic_return=223.39614868164062
# global_step=6683488, episodic_return=126.76079559326172
# SPS: 870
# global_step=6684880, episodic_return=225.6377716064453
# global_step=6686080, episodic_return=133.2403106689453
# global_step=6686304, episodic_return=-37.24489974975586
# global_step=6686576, episodic_return=107.81298065185547
# global_step=6688576, episodic_return=228.69265747070312
# global_step=6688928, episodic_return=83.44707489013672
# global_step=6690352, episodic_return=210.10397338867188
# global_step=6690400, episodic_return=138.4003143310547
# global_step=6690800, episodic_return=120.57551574707031
# global_step=6692256, episodic_return=192.02976989746094
# global_step=6692320, episodic_return=150.6023712158203
# global_step=6694192, episodic_return=132.62484741210938
# global_step=6694560, episodic_return=141.97181701660156
# global_step=6694768, episodic_return=220.12847900390625
# global_step=6697200, episodic_return=131.72523498535156
# global_step=6698000, episodic_return=92.54653930664062
# global_step=6699136, episodic_return=-40.48860168457031
# global_step=6699488, episodic_return=139.77328491210938
# global_step=6700880, episodic_return=111.84661865234375
# global_step=6700992, episodic_return=156.26852416992188
# global_step=6701536, episodic_return=-14.133369445800781
# global_step=6702080, episodic_return=151.29502868652344
# global_step=6702304, episodic_return=125.80075073242188
# global_step=6702576, episodic_return=133.8021240234375
# global_step=6703584, episodic_return=-25.566131591796875
# global_step=6704576, episodic_return=117.60009765625
# global_step=6704688, episodic_return=-50.877777099609375
# global_step=6704752, episodic_return=253.16949462890625
# global_step=6706352, episodic_return=116.1338119506836
# global_step=6706400, episodic_return=118.32540130615234
# global_step=6706800, episodic_return=119.28473663330078
# global_step=6708256, episodic_return=133.47178649902344
# global_step=6708320, episodic_return=116.96741485595703
# global_step=6710560, episodic_return=125.5643539428711
# global_step=6713824, episodic_return=219.63217163085938
# global_step=6714000, episodic_return=131.50343322753906
# global_step=6716688, episodic_return=208.5235595703125
# global_step=6716992, episodic_return=142.09642028808594
# SPS: 870
# global_step=6717536, episodic_return=139.4690399169922
# global_step=6718080, episodic_return=119.55496978759766
# global_step=6718304, episodic_return=122.24836730957031
# global_step=6718576, episodic_return=149.89669799804688
# global_step=6719584, episodic_return=82.87918853759766
# global_step=6720576, episodic_return=90.18856811523438
# global_step=6720688, episodic_return=100.21613311767578
# global_step=6720752, episodic_return=109.48058319091797
# global_step=6721808, episodic_return=186.33175659179688
# global_step=6721984, episodic_return=-36.05137252807617
# global_step=6722352, episodic_return=136.82479858398438
# global_step=6722400, episodic_return=109.29873657226562
# global_step=6722640, episodic_return=-57.32313919067383
# global_step=6722800, episodic_return=136.7688751220703
# global_step=6723632, episodic_return=229.22955322265625
# global_step=6724320, episodic_return=134.10874938964844
# global_step=6724576, episodic_return=222.78604125976562
# global_step=6725040, episodic_return=-11.314323425292969
# global_step=6725520, episodic_return=29.413726806640625
# global_step=6725920, episodic_return=-25.541412353515625
# global_step=6728368, episodic_return=221.03440856933594
# global_step=6729280, episodic_return=23.062217712402344
# global_step=6729824, episodic_return=140.51913452148438
# global_step=6729840, episodic_return=210.64682006835938
# global_step=6730000, episodic_return=121.71568298339844
# global_step=6730704, episodic_return=228.5973358154297
# global_step=6733536, episodic_return=142.712890625
# global_step=6734576, episodic_return=120.72701263427734
# global_step=6735840, episodic_return=186.36782836914062
# global_step=6737808, episodic_return=123.0318374633789
# global_step=6738400, episodic_return=99.93243408203125
# global_step=6738464, episodic_return=5.6986083984375
# global_step=6738800, episodic_return=147.1934814453125
# global_step=6739632, episodic_return=119.21043395996094
# global_step=6740320, episodic_return=118.0504150390625
# global_step=6740400, episodic_return=196.28005981445312
# global_step=6740720, episodic_return=234.84017944335938
# global_step=6741040, episodic_return=141.4663848876953
# global_step=6741520, episodic_return=133.04820251464844
# global_step=6741920, episodic_return=147.93601989746094
# global_step=6745280, episodic_return=111.27297973632812
# global_step=6745440, episodic_return=5.674110412597656
# global_step=6745824, episodic_return=133.00485229492188
# global_step=6746000, episodic_return=103.31717681884766
# global_step=6746144, episodic_return=230.99374389648438
# global_step=6746704, episodic_return=138.8961639404297
# global_step=6750032, episodic_return=250.3804931640625
# SPS: 869
# global_step=6750576, episodic_return=122.02323150634766
# global_step=6750816, episodic_return=235.48983764648438
# global_step=6753808, episodic_return=111.6216812133789
# global_step=6754400, episodic_return=115.7562026977539
# global_step=6754464, episodic_return=102.36544036865234
# global_step=6754800, episodic_return=134.3831787109375
# global_step=6755008, episodic_return=-58.54989242553711
# global_step=6756144, episodic_return=220.73785400390625
# global_step=6756320, episodic_return=132.80088806152344
# global_step=6756400, episodic_return=96.96622467041016
# global_step=6757040, episodic_return=75.8481216430664
# global_step=6757520, episodic_return=104.01875305175781
# global_step=6757920, episodic_return=125.77666473388672
# global_step=6760816, episodic_return=229.63629150390625
# global_step=6760976, episodic_return=-0.6607513427734375
# global_step=6761280, episodic_return=131.2026824951172
# global_step=6761600, episodic_return=224.404052734375
# global_step=6761824, episodic_return=119.76006317138672
# global_step=6762144, episodic_return=119.8024673461914
# global_step=6762624, episodic_return=240.6917266845703
# global_step=6762704, episodic_return=115.12641143798828
# global_step=6765936, episodic_return=-28.813140869140625
# global_step=6766096, episodic_return=-31.4034423828125
# global_step=6766768, episodic_return=183.87994384765625
# global_step=6767136, episodic_return=205.72512817382812
# global_step=6768768, episodic_return=223.923583984375
# global_step=6770400, episodic_return=129.42762756347656
# global_step=6771008, episodic_return=100.53842163085938
# global_step=6772320, episodic_return=112.55140686035156
# global_step=6772400, episodic_return=136.194580078125
# global_step=6773520, episodic_return=124.72238159179688
# global_step=6773920, episodic_return=95.18022918701172
# global_step=6776816, episodic_return=131.53126525878906
# global_step=6776976, episodic_return=128.87063598632812
# global_step=6777056, episodic_return=204.06027221679688
# global_step=6777280, episodic_return=128.82974243164062
# global_step=6778144, episodic_return=149.30906677246094
# global_step=6778704, episodic_return=139.09368896484375
# global_step=6778976, episodic_return=228.8825225830078
# global_step=6781312, episodic_return=9.681831359863281
# global_step=6781936, episodic_return=107.08177185058594
# global_step=6782096, episodic_return=112.91497039794922
# global_step=6782768, episodic_return=109.92510986328125
# SPS: 869
# global_step=6783136, episodic_return=151.42442321777344
# global_step=6784768, episodic_return=129.06500244140625
# global_step=6786400, episodic_return=105.82032012939453
# global_step=6788384, episodic_return=214.93515014648438
# global_step=6788400, episodic_return=120.3170394897461
# global_step=6789520, episodic_return=134.63104248046875
# global_step=6789920, episodic_return=129.81419372558594
# global_step=6791200, episodic_return=230.60467529296875
# global_step=6792976, episodic_return=107.73857116699219
# global_step=6793056, episodic_return=143.46466064453125
# global_step=6793280, episodic_return=114.81080627441406
# global_step=6793968, episodic_return=-1.5923919677734375
# global_step=6794144, episodic_return=106.5020980834961
# global_step=6794704, episodic_return=97.03224182128906
# global_step=6794976, episodic_return=123.09516143798828
# global_step=6796144, episodic_return=237.12026977539062
# global_step=6796240, episodic_return=178.3037567138672
# global_step=6797312, episodic_return=124.60205078125
# global_step=6797584, episodic_return=11.2066650390625
# global_step=6797936, episodic_return=94.49055480957031
# global_step=6798480, episodic_return=227.17214965820312
# global_step=6799696, episodic_return=215.48443603515625
# global_step=6800752, episodic_return=27.46631622314453
# global_step=6800768, episodic_return=133.6643829345703
# global_step=6802032, episodic_return=-12.870857238769531
# global_step=6802400, episodic_return=116.1854019165039
# global_step=6803168, episodic_return=218.9436798095703
# global_step=6804400, episodic_return=127.33721923828125
# global_step=6805920, episodic_return=106.63220977783203
# global_step=6807200, episodic_return=142.83822631835938
# global_step=6808736, episodic_return=233.96629333496094
# global_step=6808816, episodic_return=9.533195495605469
# global_step=6810144, episodic_return=100.03004455566406
# global_step=6810704, episodic_return=113.77409362792969
# global_step=6810976, episodic_return=151.05728149414062
# global_step=6812144, episodic_return=114.34425354003906
# global_step=6813584, episodic_return=139.4730224609375
# global_step=6813936, episodic_return=130.54322814941406
# global_step=6814480, episodic_return=116.74434661865234
# global_step=6814752, episodic_return=16.5316162109375
# global_step=6815696, episodic_return=126.72428894042969
# SPS: 869
# global_step=6816752, episodic_return=109.1832504272461
# global_step=6816768, episodic_return=131.58816528320312
# global_step=6818032, episodic_return=125.17024993896484
# global_step=6818400, episodic_return=138.75892639160156
# global_step=6820336, episodic_return=208.61212158203125
# global_step=6821520, episodic_return=212.35821533203125
# global_step=6821920, episodic_return=130.27333068847656
# global_step=6822080, episodic_return=217.04653930664062
# global_step=6823104, episodic_return=243.0123291015625
# global_step=6823200, episodic_return=147.44338989257812
# global_step=6823792, episodic_return=161.74594116210938
# global_step=6823824, episodic_return=176.92942810058594
# global_step=6824816, episodic_return=115.61917877197266
# global_step=6826144, episodic_return=91.26573181152344
# global_step=6826704, episodic_return=128.53411865234375
# global_step=6826976, episodic_return=122.47246551513672
# global_step=6828144, episodic_return=137.98423767089844
# global_step=6829584, episodic_return=103.6094741821289
# global_step=6830416, episodic_return=217.24354553222656
# global_step=6830752, episodic_return=165.3401641845703
# global_step=6832224, episodic_return=226.87332153320312
# global_step=6832752, episodic_return=159.39695739746094
# global_step=6835584, episodic_return=233.3714599609375
# global_step=6837520, episodic_return=88.23289489746094
# global_step=6837920, episodic_return=120.81584930419922
# global_step=6838080, episodic_return=105.86198425292969
# global_step=6839200, episodic_return=118.86761474609375
# global_step=6839792, episodic_return=123.16044616699219
# global_step=6839824, episodic_return=126.59033203125
# global_step=6840816, episodic_return=137.34974670410156
# global_step=6842144, episodic_return=108.16161346435547
# global_step=6842704, episodic_return=129.4069061279297
# global_step=6842976, episodic_return=139.9951629638672
# global_step=6843984, episodic_return=228.2860565185547
# global_step=6844144, episodic_return=141.1044921875
# ...
# global_step=9800720, episodic_return=225.03903198242188
# global_step=9801424, episodic_return=122.8166275024414
# global_step=9802400, episodic_return=20.130813598632812
# global_step=9802640, episodic_return=10.52508544921875
# global_step=9803024, episodic_return=215.68637084960938
# global_step=9803072, episodic_return=14.7391357421875
# global_step=9803616, episodic_return=117.56047058105469
# global_step=9804032, episodic_return=196.95941162109375
# global_step=9805408, episodic_return=187.52857971191406
# global_step=9806480, episodic_return=155.91256713867188
# global_step=9808480, episodic_return=116.39657592773438
# global_step=9808592, episodic_return=108.06314086914062
# global_step=9810576, episodic_return=223.6123046875
# global_step=9811120, episodic_return=206.21603393554688
# global_step=9811760, episodic_return=107.2958984375
# global_step=9812608, episodic_return=-46.50861358642578
# global_step=9814192, episodic_return=154.5476837158203
# global_step=9814368, episodic_return=125.99909973144531
# global_step=9816144, episodic_return=77.03309631347656
# global_step=9816672, episodic_return=234.75680541992188
# global_step=9816720, episodic_return=97.3997573852539
# global_step=9818224, episodic_return=183.93150329589844
# global_step=9818400, episodic_return=132.11962890625
# global_step=9819024, episodic_return=128.39578247070312
# global_step=9819072, episodic_return=122.03616333007812
# global_step=9819616, episodic_return=74.06256103515625
# global_step=9820032, episodic_return=95.31251525878906
# global_step=9821408, episodic_return=129.87350463867188
# global_step=9821632, episodic_return=212.10433959960938
# global_step=9821664, episodic_return=-18.624008178710938
# global_step=9822480, episodic_return=141.65980529785156
# global_step=9825760, episodic_return=-14.867912292480469
# global_step=9826576, episodic_return=126.49932861328125
# global_step=9826912, episodic_return=189.89695739746094
# global_step=9827120, episodic_return=111.03034210205078
# global_step=9828048, episodic_return=187.75746154785156
# global_step=9828608, episodic_return=145.9933319091797
# global_step=9830368, episodic_return=149.37356567382812
# SPS: 844
# global_step=9832144, episodic_return=145.24061584472656
# global_step=9832672, episodic_return=122.5682601928711
# global_step=9832720, episodic_return=141.13388061523438
# global_step=9834224, episodic_return=134.33670043945312
# global_step=9835024, episodic_return=130.7003631591797
# global_step=9835072, episodic_return=158.16033935546875
# global_step=9835296, episodic_return=199.1912841796875
# global_step=9836032, episodic_return=101.3812255859375
# global_step=9837408, episodic_return=135.77337646484375
# global_step=9837648, episodic_return=209.5428924560547
# global_step=9837664, episodic_return=148.74444580078125
# global_step=9838176, episodic_return=160.70144653320312
# global_step=9838928, episodic_return=222.02406311035156
# global_step=9839824, episodic_return=-9.157112121582031
# global_step=9840064, episodic_return=19.485984802246094
# global_step=9840272, episodic_return=231.04420471191406
# global_step=9840704, episodic_return=219.10972595214844
# global_step=9841760, episodic_return=121.3253402709961
# global_step=9841968, episodic_return=210.12548828125
# global_step=9842576, episodic_return=119.7640609741211
# global_step=9843120, episodic_return=113.65235900878906
# global_step=9844608, episodic_return=127.67440032958984
# global_step=9846240, episodic_return=192.00563049316406
# global_step=9848144, episodic_return=127.86493682861328
# global_step=9849232, episodic_return=-14.135986328125
# global_step=9851296, episodic_return=107.16085815429688
# global_step=9852032, episodic_return=-47.169151306152344
# global_step=9853408, episodic_return=109.3192367553711
# global_step=9853648, episodic_return=115.34597778320312
# global_step=9853664, episodic_return=144.8383331298828
# global_step=9854176, episodic_return=103.81108093261719
# global_step=9854928, episodic_return=114.21508026123047
# global_step=9855824, episodic_return=120.84256744384766
# global_step=9856272, episodic_return=111.72683715820312
# global_step=9856704, episodic_return=110.83470916748047
# global_step=9857248, episodic_return=-21.912017822265625
# global_step=9857760, episodic_return=143.75732421875
# global_step=9857968, episodic_return=107.4844970703125
# global_step=9858576, episodic_return=87.9872055053711
# global_step=9858816, episodic_return=-28.522384643554688
# global_step=9859120, episodic_return=106.04951477050781
# global_step=9861984, episodic_return=250.10716247558594
# global_step=9862240, episodic_return=123.53076171875
# SPS: 844
# global_step=9864096, episodic_return=220.22117614746094
# global_step=9864816, episodic_return=201.1879425048828
# global_step=9865232, episodic_return=149.4554901123047
# global_step=9865968, episodic_return=208.32676696777344
# global_step=9866128, episodic_return=192.47076416015625
# global_step=9867296, episodic_return=127.71437072753906
# global_step=9868032, episodic_return=146.98709106445312
# global_step=9868656, episodic_return=9.812629699707031
# global_step=9869648, episodic_return=124.78758239746094
# global_step=9870176, episodic_return=119.34269714355469
# global_step=9870928, episodic_return=182.734130859375
# global_step=9871824, episodic_return=123.42808532714844
# global_step=9872272, episodic_return=135.40176391601562
# global_step=9872624, episodic_return=-29.569503784179688
# global_step=9873248, episodic_return=133.3390655517578
# global_step=9874576, episodic_return=136.32989501953125
# global_step=9874816, episodic_return=139.67535400390625
# global_step=9876896, episodic_return=18.253936767578125
# global_step=9877984, episodic_return=123.48963165283203
# global_step=9878240, episodic_return=63.72511672973633
# global_step=9879376, episodic_return=226.43890380859375
# global_step=9879424, episodic_return=26.759841918945312
# global_step=9880064, episodic_return=181.6224822998047
# global_step=9880320, episodic_return=187.4114227294922
# global_step=9880560, episodic_return=222.60940551757812
# global_step=9880816, episodic_return=119.15492248535156
# global_step=9881968, episodic_return=137.54415893554688
# global_step=9882128, episodic_return=120.75000762939453
# global_step=9882752, episodic_return=193.10992431640625
# global_step=9882976, episodic_return=201.91964721679688
# global_step=9884032, episodic_return=97.0109634399414
# global_step=9884656, episodic_return=121.44315338134766
# global_step=9885520, episodic_return=192.5452880859375
# global_step=9885648, episodic_return=103.2221450805664
# global_step=9887392, episodic_return=29.7947998046875
# global_step=9887824, episodic_return=138.51943969726562
# global_step=9887936, episodic_return=205.8192901611328
# global_step=9888688, episodic_return=154.65606689453125
# global_step=9890816, episodic_return=138.99139404296875
# global_step=9892176, episodic_return=189.51773071289062
# global_step=9894576, episodic_return=184.98394775390625
# global_step=9895376, episodic_return=143.68743896484375
# SPS: 844
# global_step=9896064, episodic_return=118.71800231933594
# global_step=9896560, episodic_return=147.0714111328125
# global_step=9896944, episodic_return=204.0238037109375
# global_step=9897968, episodic_return=142.3744354248047
# global_step=9898128, episodic_return=122.91556549072266
# global_step=9898272, episodic_return=173.185546875
# global_step=9898976, episodic_return=132.53787231445312
# global_step=9900032, episodic_return=134.4661865234375
# global_step=9900656, episodic_return=99.038818359375
# global_step=9901520, episodic_return=111.48102569580078
# global_step=9901648, episodic_return=123.22595977783203
# global_step=9901904, episodic_return=209.9507598876953
# global_step=9903392, episodic_return=118.07923126220703
# global_step=9903824, episodic_return=112.69824981689453
# global_step=9906816, episodic_return=127.8952407836914
# global_step=9907360, episodic_return=197.04116821289062
# global_step=9909024, episodic_return=236.73448181152344
# global_step=9910576, episodic_return=113.21884155273438
# global_step=9911376, episodic_return=123.03777313232422
# global_step=9912560, episodic_return=103.94938659667969
# global_step=9912944, episodic_return=132.84896850585938
# global_step=9913968, episodic_return=146.2698211669922
# global_step=9913984, episodic_return=210.56317138671875
# global_step=9914128, episodic_return=100.9020767211914
# global_step=9914272, episodic_return=139.4627685546875
# global_step=9916032, episodic_return=113.8318099975586
# global_step=9916656, episodic_return=132.16014099121094
# global_step=9916704, episodic_return=233.78334045410156
# global_step=9917616, episodic_return=-4.869346618652344
# global_step=9917648, episodic_return=141.38992309570312
# global_step=9917904, episodic_return=100.91954040527344
# global_step=9918336, episodic_return=27.14832305908203
# global_step=9919392, episodic_return=108.64359283447266
# global_step=9919824, episodic_return=66.70036315917969
# global_step=9920480, episodic_return=22.67547607421875
# global_step=9921312, episodic_return=-7.697113037109375
# global_step=9921888, episodic_return=-16.0006103515625
# global_step=9923360, episodic_return=124.70426940917969
# global_step=9925024, episodic_return=123.68444061279297
# global_step=9927280, episodic_return=208.35614013671875
# global_step=9927328, episodic_return=26.76287078857422
# global_step=9927376, episodic_return=104.12029266357422
# global_step=9928560, episodic_return=97.82901000976562
# SPS: 844
# global_step=9929040, episodic_return=0.34625244140625
# global_step=9929968, episodic_return=132.2599334716797
# global_step=9929984, episodic_return=110.87689208984375
# global_step=9930128, episodic_return=123.09070587158203
# global_step=9931904, episodic_return=4.3055419921875
# global_step=9932032, episodic_return=130.58184814453125
# global_step=9933616, episodic_return=131.27195739746094
# global_step=9933648, episodic_return=112.07442474365234
# global_step=9934336, episodic_return=111.59496307373047
# global_step=9934448, episodic_return=31.923980712890625
# global_step=9935824, episodic_return=129.41192626953125
# global_step=9936480, episodic_return=121.46319580078125
# global_step=9937216, episodic_return=-20.148239135742188
# global_step=9937312, episodic_return=141.67971801757812
# global_step=9937888, episodic_return=132.94845581054688
# global_step=9938288, episodic_return=198.71371459960938
# global_step=9938624, episodic_return=-68.99565887451172
# global_step=9940480, episodic_return=142.45822143554688
# global_step=9941648, episodic_return=-28.355331420898438
# global_step=9941840, episodic_return=-9.631324768066406
# global_step=9943328, episodic_return=98.38953399658203
# global_step=9943376, episodic_return=105.76507568359375
# global_step=9944560, episodic_return=128.84765625
# global_step=9944976, episodic_return=191.78890991210938
# global_step=9945040, episodic_return=116.57966613769531
# global_step=9945968, episodic_return=111.90037536621094
# global_step=9946128, episodic_return=112.66593170166016
# global_step=9946272, episodic_return=-33.45269775390625
# global_step=9947904, episodic_return=137.84815979003906
# global_step=9949616, episodic_return=94.42585754394531
# global_step=9950768, episodic_return=-1.8550567626953125
# global_step=9951296, episodic_return=233.50262451171875
# global_step=9951712, episodic_return=226.24655151367188
# global_step=9951824, episodic_return=118.91088104248047
# global_step=9952480, episodic_return=112.10321807861328
# global_step=9953376, episodic_return=219.52139282226562
# global_step=9954384, episodic_return=226.37400817871094
# global_step=9954624, episodic_return=129.94532775878906
# global_step=9955488, episodic_return=144.27536010742188
# global_step=9955856, episodic_return=238.6669921875
# global_step=9955920, episodic_return=-56.941200256347656
# global_step=9956480, episodic_return=142.4605712890625
# global_step=9957648, episodic_return=165.10443115234375
# global_step=9959328, episodic_return=137.38827514648438
# global_step=9959872, episodic_return=-25.447250366210938
# global_step=9960560, episodic_return=82.93962860107422
# global_step=9960976, episodic_return=106.07391357421875
# global_step=9961040, episodic_return=148.21070861816406
# SPS: 844
# global_step=9961632, episodic_return=159.51751708984375
# global_step=9961968, episodic_return=139.22299194335938
# global_step=9963136, episodic_return=187.7352294921875
# global_step=9963456, episodic_return=169.97760009765625
# global_step=9964608, episodic_return=208.18960571289062
# global_step=9967152, episodic_return=214.44448852539062
# global_step=9967600, episodic_return=163.62872314453125
# global_step=9967712, episodic_return=132.35214233398438
# global_step=9968480, episodic_return=114.58335876464844
# global_step=9968912, episodic_return=172.7493133544922
# global_step=9969376, episodic_return=111.43049621582031
# global_step=9969824, episodic_return=243.390625
# global_step=9970384, episodic_return=115.97721862792969
# global_step=9970624, episodic_return=135.3533477783203
# global_step=9971920, episodic_return=122.15339660644531
# global_step=9972480, episodic_return=101.99064636230469
# global_step=9973664, episodic_return=212.0968017578125
# global_step=9975872, episodic_return=99.92407989501953
# global_step=9976352, episodic_return=226.71875
# global_step=9976560, episodic_return=187.74960327148438
# global_step=9977040, episodic_return=140.0937042236328
# global_step=9977968, episodic_return=133.324462890625
# global_step=9978576, episodic_return=195.85195922851562
# global_step=9979136, episodic_return=141.61373901367188
# global_step=9979456, episodic_return=127.07420349121094
# global_step=9981168, episodic_return=242.5237274169922
# global_step=9983152, episodic_return=140.61056518554688
# global_step=9983312, episodic_return=205.61492919921875
# global_step=9983712, episodic_return=108.81092834472656
# global_step=9984480, episodic_return=154.47711181640625
# global_step=9985376, episodic_return=78.71662139892578
# global_step=9985824, episodic_return=135.6710968017578
# global_step=9987920, episodic_return=109.22074890136719
# global_step=9988480, episodic_return=155.36912536621094
# global_step=9989664, episodic_return=144.77981567382812
# global_step=9991872, episodic_return=127.36247253417969
# global_step=9992560, episodic_return=96.89470672607422
# global_step=9993968, episodic_return=86.06759643554688
# SPS: 843
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# [swscaler @ 0x5ac5380] Warning: data is not aligned! This can lead to a speed loss
# ℹ Pushing repo Weiming1122/ppo-LunarLander-v2-unit8 to the Hugging Face
# Hub
# events.out.tfevents.1704532881.17221c933492.3564.0:   0% 0.00/2.06M [00:00<?, ?B/s]
# model.pt:   0% 0.00/43.0k [00:00<?, ?B/s]
#
# events.out.tfevents.1704532881.17221c933492.3564.0:   1% 16.4k/2.06M [00:00<00:23, 86.6kB/s]
# model.pt: 100% 43.0k/43.0k [00:00<00:00, 94.6kB/s]
# events.out.tfevents.1704532881.17221c933492.3564.0: 100% 2.06M/2.06M [00:00<00:00, 2.78MB/s]
#
#
# Upload 2 LFS files: 100% 2/2 [00:00<00:00,  2.06it/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/Weiming1122/ppo-LunarLander-v2-unit8/tree/main/
